# %%
# Resources for evaluation.
PROJECT_ROOT_PATH    = '../../../..'
DETECT_DATA_PATH     = PROJECT_ROOT_PATH + '/tmp/detect/data'
TOKENIZE_DATA_PATH   = PROJECT_ROOT_PATH + '/tmp/tokenize/data'
RESOURCE_PATH        = PROJECT_ROOT_PATH + '/ocrrect-experiment/src/main/resources'
WORDS_TRAIN_PATH     = DETECT_DATA_PATH + '/words.train.tsv'
WORDS_TEST_PATH      = DETECT_DATA_PATH + '/words.test.tsv'
WORDS_PTB_PATH       = DETECT_DATA_PATH + '/words.ptb.tsv'
WORDS_WS_PATH        = DETECT_DATA_PATH + '/words.ws.tsv'
TOKENS_ELEPHANT_PATH = TOKENIZE_DATA_PATH + '/tokens.elephant.txt'
TEXT_OCR_PATH        = RESOURCE_PATH + '/mibio-ocr/ocr'
ERROR_GT_PATH        = RESOURCE_PATH + '/mibio-ocr/error.gt.tsv'
TOKEN_GT_PATH        = RESOURCE_PATH + '/mibio-ocr/ocr.token.tsv'
TOKEN_GT_HYPHEN_PATH = RESOURCE_PATH + '/mibio-ocr/ocr.token.hyphen.tsv'

EXP_RES_PATH     = PROJECT_ROOT_PATH + '/ocrrect-experiment/src/main/resources'
WASTE_BNC_PATH   = EXP_RES_PATH + '/waste.bnc.tokenize.fcgi.mod.txt'
WASTE_BROWN_PATH = EXP_RES_PATH + '/waste.brown.tokenize.fcgi.txt'
WASTE_WSJ_PATH   = EXP_RES_PATH + '/waste.wsj.tokenize.fcgi.txt'

# %% [markdown]
# ### Token generation

# %%
""" Concat OCR text. """

TEXT_PATH = TOKENIZE_DATA_PATH + '/text.ocr.txt' 

import os
import glob

if not os.path.exists(TOKENIZE_DATA_PATH):
    os.makedirs(TOKENIZE_DATA_PATH)

with open(TEXT_PATH, 'w') as file:
    txt = ''.join([open(f, 'r').read() for f in glob.glob(TEXT_OCR_PATH + '/*')])
    file.write(txt)

# %%
def gen_elephant_dict():
    tks = [l[:-1] for l in open(TOKENS_ELEPHANT_PATH, 'r')]
    tk_idx, tk_pt = 0, 0 # current reading position

    # c_pos = 0
    positioned = {}
    for k, v in TOKENS_GT_DICT.items():
        #for c in v.replace('↵', ''):
        for i, c in enumerate(v):
            # skip newline and whitespace char
            if ord(c) == 8629 or c == ' ':
                continue

            tk_c = tks[tk_idx][tk_pt]

            # if matches.
            if ord(c) == ord(tk_c):
                # if it is the first character in the token, then record this position.
                if tk_pt == 0:
                    positioned[k + i] = tks[tk_idx]
                    # print(str(k + i) + ' ' + tks[tk_idx])

            else:
                raise ValueError(str(k) + ' ' + v + ' ' + str(i) + 
                                 ' (' + c + ',' + tk_c + ') ' + 
                                 ' (' + str(ord(c)) + ',' + str(ord(tk_c)) + ') ' + 
                                 tks[tk_idx] + ' ' + str(tk_pt)
                                )

            # move the pointer to the next char in tks
            tk_pt += 1
            if tk_pt == len(tks[tk_idx]):
                tk_idx += 1; tk_pt = 0

    return positioned

# %%
def gen_waste_dict(path):
    tks = []
    with open(path, 'r') as file:
        for lidx, line in enumerate(file):
            if lidx == 0 or len(line) == 1: continue
            tk, _, _ = line.split('\t', 3)
            tks.append(tk)
            
    tk_idx, tk_pt = 0, 0 # current reading position

    # c_pos = 0
    positioned = {}
    for k, v in TOKENS_GT_DICT.items():
        #for c in v.replace('↵', ''):
        v = v.replace('-↵', '').replace('ﬃ', 'ffi').replace('ﬂ', 'fl')
        for i, c in enumerate(v):
            # skip newline and whitespace char
            if ord(c) == 8629 or c == ' ':
                continue

            tk_c = tks[tk_idx][tk_pt]

            # if matches.
            if ord(c) == ord(tk_c):
                # if it is the first character in the token, then record this position.
                if tk_pt == 0:
                    positioned[k + i] = tks[tk_idx]
                    # print(str(k + i) + ' ' + tks[tk_idx])
                    
            # ignore the missing hyphen
            elif c is '-':
                continue

            else:
                print(c is '-')
                print(len(v) > i + 1)
                raise ValueError(str(k) + ' ' + v + ' ' + str(i) + 
                                 ' (' + c + ',' + tk_c + ') ' + 
                                 ' (' + str(ord(c)) + ',' + str(ord(tk_c)) + ') ' + 
                                 tks[tk_idx] + ' ' + str(tk_pt)
                                )

            # move the pointer to the next char in tks
            tk_pt += 1
            if tk_pt == len(tks[tk_idx]):
                tk_idx += 1; tk_pt = 0
            
    return positioned

dic = gen_waste_dict(WASTE_BNC_PATH)
# print('\n'.join(str(k) + ' ' + v for k, v in sorted(dic.items())))

# %%
""" Evaluate tokenization methods. """

print('elephant'); print_eval_method(dic=gen_elephant_dict())
# Out:
# elephant
# tp:  94685  fp:   4895  fn:   7042  prec: 0.9508  recall: 0.9308  f: 0.9407  err: 0.1120

# %% [markdown]
# ### Tokenization Accuracy Evaluation
#
# We evalute the accuracy of the proposed tokenization on **MiBio** dataset.

# %%
""" Generate the ground truth token map. """

import csv
import pandas as pd


def read_token_tsv(path):
    """ Read a token TSV file as a dictionary that maps the starting position to
        the token string name.
    """
    col_names = ['name', 'pos_str', 'pos_end']
    df = pd.read_table(open(path, 'r'),
                       header=None,
                       quoting=csv.QUOTE_NONE,
                       names=col_names)
    return dict((pos, name) for _, (name, pos, _) in df.iterrows())


TOKENS_GT_DICT = read_token_tsv(TOKEN_GT_PATH) 


# print('\n'.join(str(k) + ' ' + v for k, v in sorted(TOKENS_GT_DICT.items())))

# %%
""" Evaluation metrics. """


def read_word_tsv(path):
    """ Read a word TSV file as a dictionary that maps the starting position to
        the word string name.
    """
    col_names = ['w-4', 'w-3', 'w-2', 'w-1', 'w', 'w+1', 'w+2', 'w+3', 'pos']
    df = pd.read_table(open(path, 'r'),
                       header=None,
                       quoting=csv.QUOTE_NONE,
                       names=col_names)
    return dict((pos, name) for _, (_, _, _, _, name, _, _, _, pos)
                in df.iterrows())


def _match_tokens(model_dict):
    """ Evaluate the accuracy of the model generated words.
    """
    def get_gt_matches(pos):
        """ Look the position and 4 character ahead for valid words as the
            ground truth mapping words.
        """
        gt_matches = []
        for offset in range(4):
            try:
                gt_matches.append(TOKENS_GT_DICT[pos + offset])
            except KeyError:
                pass
        return gt_matches
    
    def match_gt(name, gt_name):
        """ Returns true if a model generated word string matches with the
            ground truth.
        """
        #print('(' + name + ',' + gt_name + ')', end='')
        if gt_name == name:
            return True
        if '↵' in gt_name:
            p1, p2 = re.split(r'-\s*↵', gt_name)
            #print('(' + (p1 + p2) + ',' + gt_name + ')', end='')
            if p1 + p2 == name or p1 + '-' + p2 == name:
                return True
        return False
        
    corr, err = 0, 0
    err_records = []  # cache of the errors.
    for pos, name in model_dict.items():
        curr = [pos, name]
        gt_matches = get_gt_matches(pos)
        curr.append(gt_matches)
        if any(match_gt(name, gt) for gt in get_gt_matches(pos)):
            corr += 1
        else:
            err_records.append(curr)
#             if len(err_records) < 100:
#             print(err_records[-1])
            err += 1
    return corr, err, err_records


def eval_method(path=None, dic=None):
    if not dic:
        dic = read_word_tsv(path)
    tp, fp, _ = _match_tokens(dic)
    fn = len(TOKENS_GT_DICT) - tp
    prec = tp / (tp + fp)
    recall = tp / (tp + fn)
    f = 2 * prec * recall / (prec + recall)
    err = (fp + fn) / (tp + fp + fn)
    return tp + fp, tp, fp, fn, prec, recall, f, err


def print_eval_method(path=None, dic=None):
    print('total: %6d  tp: %6d  fp: %6d  fn: %6d  prec: %.4f  recall: %.4f  f: %.4f  err: %.4f'
          % eval_method(path, dic))

# %%
""" Evaluate tokenization methods. """

print('ptb'); print_eval_method(path=WORDS_PTB_PATH)
print('ws');  print_eval_method(path=WORDS_WS_PATH)
print('prop'); print_eval_method(dic={**read_word_tsv(WORDS_TRAIN_PATH),
                                     **read_word_tsv(WORDS_TEST_PATH)})
# Out:
# ptb
# total: 101291  tp:  95546  fp:   5745  fn:   6163  prec: 0.9433  recall: 0.9394  f: 0.9413  err: 0.1108
# ws
# total:  87002  tp:  74388  fp:  12614  fn:  27321  prec: 0.8550  recall: 0.7314  f: 0.7884  err: 0.3493
# prop
# total: 101645  tp: 100671  fp:    974  fn:   1038  prec: 0.9904  recall: 0.9898  f: 0.9901  err: 0.0196

# %%
""" Evaluate tokenization methods. """

print('elephant'); print_eval_method(dic=gen_elephant_dict())
# Out:
# elephant
# [336, 'so-called', ['so', '-', 'called']]
# [413, 'Hang-nests', ['Hang']]
# [1150, 'classifi-', ['classifi-↵cation']]
# [1160, 'cation', []]
# [1496, 'salmon-pink', ['salmon']]
# [1530, 'blackish-brown', ['blackish']]
# [1567, 'lilacine-greyisli', ['lilacine']]
# [1585, 'shell-markings', ['shell']]
# [1606, 'call-notes', ['call']]
# [1951, 'Familx-', ['Familx']]
# [1959, 'ORIOL', ['ORIOL ID^E']]
# [1965, 'ID^E', []]
# [2209, 'south-eastwards', ['south']]
# [2536, 'south-eastern', ['south']]
# [2964, 'unsuc-', ['unsuc-↵cessful']]
# [2971, 'cessful', []]
# [3167, 'H', ['H.', 'W.']]
# [3168, '.', ['W.']]
# [3170, 'W', ['W.', 'Feildeu']]
# [3171, '.', ['Feildeu']]
# [3456, 'gamboge-yellow', ['gamboge']]
# [3489, '(excepting', ['(', 'excepting']]
# [3526, 'primary-coverts', ['primary']]
# [3682, 'j^ellowish-white', ['j^ellowish']]
# [3717, 'tail-feathers', ['tail']]
# [3891, 'reddish-ochreous', ['reddish']]
# [3915, 'leaden-grey', ['leaden']]
# [4580, 'Thrush-like', ['Thrush']]
# [5410, 'monkey-nature', ['monkey']]
# [5473, 'j', ['j ust']]
# [5475, 'ust', []]
# [5816, 'broad-leaved', ['broad']]
# [5874, 'birch-bark', ['birch']]
# [5891, 'etc', ['etc.']]
# [5894, '.', [',', 'carefully']]
# [6108, 'milk-white', ['milk']]
# [6163, 'occasionall', ["occasionall}'"]]
# [6174, '}', ['a']]
# [6175, "'", ['a']]
# [6191, 'shell-spots', ['shell']]
# [6269, 'call-note', ['call']]
# [6305, 'flute-like', ['flute']]
# [6325, 'alarm-note', ['alarm']]
# [6416, '?', ["?( '/■<■(•/"]]
# [6417, '(', []]
# [6419, "'/■<■(", []]
# [6425, '•', [',']]
# [6426, '/', [',', '//']]
# [6429, '/', ['//', ',']]
# [6430, '/', [',', 'vec-o']]
# [6433, "vec-o'", ['vec-o']]
# [6439, "'", ["''", 'The']]
# [6440, "'", ['The']]
# [6446, 'Rev', ['Rev.']]
# [6449, '.', ['H.']]
# [6451, 'H', ['H.', 'A.']]
# [6452, '.', ['A.']]
# [6454, 'A', ['A.', 'IMacphersou']]
# [6455, '.', ['IMacphersou']]
# [6498, 'cat-like', ['cat', '-']]
# [6549, 'p', ['p.', '467']]
# [6550, '.', ['467']]
# [6769, 'eas}', ["eas}'"]]
# [6773, "'", ['to']]
# [7035, 'largel', ["largel}'"]]
# [7041, '}', ['of']]
# [7042, "'", ['of']]
# [7333, 'cage-bird', ['cage']]
# [7470, 'an', ["an}'"]]
# [7472, '}', [',']]
# [7473, "'", [',', 'for']]
# [7711, 'extremelj', ["extremelj'"]]
# [7720, "'", ['probable']]
# [7756, 'tr3', ["tr3'ing"]]
# [7759, "'ing", []]
# [8012, 'oat-flour', ['oat', '-']]
# [8073, 'dog-biscuit', ['dog', '-']]
# [8132, 'advantageousl', ["advantageousl}'"]]
# [8145, '}', ['varied']]
# [8146, "'", ['varied']]
# [8413, '(which', ['(', 'which']]
# [8808, 'da}', ["da}'"]]
# [8811, "'", ['are']]
# [8909, 'Butcher-birds', ['Butcher']]
# [8940, 'well-defined', ['well']]
# [9224, 'well-defiued', ['well']]
# [9342, 'wedge-shaped', ['wedge']]
# [9420, 'well-defiued', ['well']]
# [9826, 'an}', ["an}'"]]
# [9829, "'", ['way']]
# [10112, 'Laniida', ['Laniida:']]
# [10119, ':', [',', 'as']]
# [10615, 'in-', ['in-↵deed']]
# [10619, 'deed', []]
# [10669, 'Corvi', ['Corvi)ia']]
# [10674, ')ia', [',']]
# [11070, 'Faiuiiv^LAXIILKl-', ['Faiuiiv']]
# [11087, ':', ['.']]
# [11668, 'L', ['L.', 'cxcubitor']]
# [11669, '.', ['cxcubitor']]
# [11791, 'L', ['L.', 'viajor']]
# [11792, '.', ['viajor']]
# [11830, 'Prof', ['Prof.']]
# [11834, '.', ['Collett']]
# [11861, '30-40', ['30', '-', '40']]
# [11898, 'L', ['L.', 'exaibiior']]
# [11899, '.', ['exaibiior']]
# [11927, 't3', ["t3'pical"]]
# [11929, "'pical", []]
# [12084, 'double-barred', ['double']]
# [12147, 'single-barred', ['single']]
# [12199, 'L', ['L.', 'major']]
# [12200, '.', ['major']]
# [12239, 'L', ['L.', 'excubitor']]
# [12240, '.', ['excubitor']]
# [12316, 'L', ['L.', 'major']]
# [12317, '.', ['major']]
# [12450, 'L', ['L.', 'Icncopterus']]
# [12451, '.', ['Icncopterus']]
# [12631, 'L', ['L.', 'honieyeri']]
# [12632, '.', ['honieyeri']]
# [12845, 'birds', ["birds'"]]
# [12850, "'-nesting", ['-', 'nesting']]
# [13124, '^', ['^^%']]
# [13125, '^', ['in']]
# [13126, '%', ['in']]
# [13215, 'Herts.', ['Herts']]
# [13263, 'L', ['L.', '(xcubitoy']]
# [13264, '.', ['(xcubitoy']]
# [13333, 'grey-above', ['grey']]
# [13394, 'tail-coverts', ['tail']]
# [13700, 'ear-coverts', ['ear', '-']]
# [13923, 'greyish-brown', ['greyish']]
# [13973, 'dull-white', ['dull']]
# [14040, 'bell', ['bell}-']]
# [14044, '}-', [';']]
# [14258, 'Red-backed', ['Red', '-']]
# [14303, 'countr}', ['countr}^']]
# [14310, '^', ['the']]
# [14587, 'new-born', ['new', '-']]
# [14636, 'Parus', ['Parus.']]
# [14641, '.', ['or']]
# [14672, 'slow-worms', ['slow']]
# [14690, 'etc', ['etc.']]
# [14693, '.', [':', 'it']]
# [14726, 'Red-backed', ['Red', '-']]
# [15198, 'bulk', ["bulk}'"]]
# [15202, '}', [',']]
# [15203, "'", [',', 'and']]
# [15532, 'well-defined', ['well']]
# [15592, 'lilac-grey', ['lilac']]
# [15603, 'shell-markings', ['shell']]
# [15893, 'Crow-family', ['Crow']]
# [15943, 'sa3', ["sa3'S"]]
# [15946, "'S", [':']]
# [16566, 'bird-lime', ['bird']]
# [16694, 'p', ['p.', '475']]
# [16695, '.', ['475']]
# [16852, 'call-notes', ['call']]
# [17311, 'song-bird', ['song']]
# [17355, 'song-birds', ['song']]
# [17423, 'Blue-bearded', ['Blue']]
# [17654, 'Family-', ['Family']]
# [17662, 'LAXIID.^', ['LAXIID.^.']]
# [17877, 'onl', ['onl}^']]
# [17880, '}^', ['four']]
# [17973, 'six:', ['six', ':']]
# [18327, 'Famtly-LANIID', ['Famtly']]
# [18341, "'E", ['.']]
# [18350, 'Red-Backed', ['Red', '-']]
# [18540, 'pen-', ['pen-↵insula']]
# [18545, 'insula', []]
# [18601, 'north-east', ['north']]
# [18675, 'pine-regions', ['pine']]
# [18840, 'North-east', ['North']]
# [19469, 'onl', ["onl}'"]]
# [19472, '}', ['a']]
# [19473, "'", ['a']]
# [19542, 'south-east', ['south']]
# [19835, 'chestnut-brown', ['chestnut']]
# [19856, 'wing-coverts', ['wing']]
# [19969, 'tail-feathers', ['tail']]
# [20095, 'ear-coverts', ['ear', '-']]
# [20170, 'tail-coverts', ['tail']]
# [20291, 'reddish-brown', ['reddish']]
# [20353, 'buffish-white', ['buffish']]
# [20565, 'ill-defined', ['ill', '-']]
# [20577, 'eye-streak', ['eye', '-']]
# [20650, 'Butcher-bird', ['Butcher']]
# [20674, 'earl}', ["earl}'"]]
# [20679, "'", ['in']]
# [21157, 'laying-time', ['laying']]
# [21271, 'frequentl', ["frequentl}'"]]
# [21280, '}', ['placed']]
# [21281, "'", ['placed']]
# [21670, 'ground-tint', ['ground']]
# [21755, 'salmon-pink', ['salmon']]
# [21798, 'red-brown', ['red', '-']]
# [21835, 'bluish-ash', ['bluish']]
# [22360, 'six-foot', ['six', '-']]
# [22640, 'Red-backed', ['Red', '-']]
# [22997, 'grass-stalks', ['grass']]
# [23078, 'well-known', ['well']]
# [23101, 'Butcher-bird', ['Butcher']]
# [23475, '(even', ['(', 'even']]
# [23633, 'Red-backed', ['Red', '-']]
# [23764, 'call-note', ['call']]
# [23884, 'p', ['p.', '446']]
# [23885, '.', ['446']]
# [23972, 'Red-backed', ['Red', '-']]
# [23993, 'Thorn-piercer', ['Thorn']]
# [24007, '(Lanius', ['(', 'Lanius']]
# [24286, 'Red-backed', ['Red', '-']]
# [24370, 'Black-cap', ['Black']]
# [24427, 'Meadow-', ['Meadow']]
# [24440, 'Tree-Pipits', ['Tree']]
# [24457, 'Song-Thrush', ['Song']]
# [24648, 'cage-birds', ['cage']]
# [24747, 'cage-bird', ['cage']]
# [24830, 'difficult', ["difficult}'"]]
# [24839, '}', ['.']]
# [24840, "'", ['.', 'This']]
# [24947, 'bird-song', ['bird']]
# [25822, 'hand-reared', ['hand']]
# [25913, 'holly-bush', ['holly']]
# [25988, 'well-built', ['well']]
# [26445, 'holly-bush', ['holly']]
# [27260, 'Singing-finch', ['Singing']]
# [27616, 'twenty-four', ['twenty']]
# [27925, 'Family-', ['Family']]
# [27933, 'LANIID', ["LANIID. 'E"]]
# [27939, '.', []]
# [27941, "'", ['.']]
# [27942, 'E', ['.']]
# [28077, 'north-east', ['north']]
# [28503, 'Turke}', ['Turke}-']]
# [28509, '-', [',', 'Asia']]
# [28632, 'lat', ['lat.']]
# [28635, '.', [',', 'also']]
# [28912, 'thirty-seven', ['thirty']]
# [29247, 'ear-', ['ear', '-']]
# [29431, 'tail-coverts', ['tail']]
# [29692, 'bnff;', ['bnff']]
# [29840, 'russet-brown', ['russet']]
# [29914, 'wing-', ['wing']]
# [30094, 'horn-brown', ['horn']]
# [30119, 'horn-brown', ['horn']]
# [30141, 'Red-backed', ['Red', '-']]
# [30196, 'thinl', ["thinl}'"]]
# [30201, '}', ['timbered']]
# [30202, "'", ['timbered']]
# [30366, 'North-', ['North-↵amptonshire']]
# [30373, 'amptonshire', []]
# [30386, 'Vol', ['Vol.']]
# [30389, '.', ['I', ',']]
# [30394, 'p', ['p.', '78']]
# [30395, '.', ['78']]
# [30548, 'olive-groves', ['olive']]
# [30670, 'look-out', ['look']]
# [30728, 'Red-backed', ['Red', '-']]
# [31424, 'GnaplialiuniJ', ['Gnaplialiuni']]
# [31669, 'Red-backed', ['Red', '-']]
# [31808, 'ver', ["ver}'"]]
# [31811, '}', ['rarel}-']]
# [31812, "'", ['rarel}-']]
# [31842, 'L', ['L.', 'potneraHus']]
# [31843, '.', ['potneraHus']]
# [31900, 'A', ['A.', 'Wright']]
# [31901, '.', ['Wright']]
# [31923, 'p', ['p.', '59']]
# [31924, '.', ['59']]
# [32369, 'well-formed', ['well']]
# [32412, 'almond-tree', ['almond']]
# [32742, 'saj', ["saj'S"]]
# [32745, "'S", [':']]
# [33144, 'call-notes', ['call']]
# [33454, 'saj', ["saj'S"]]
# [33457, "'S", ['that']]
# [33740, 'bird.', ['bird']]
# [33773, 'Red-backed', ['Red', '-']]
# [33945, 'Possiblj', ["Possiblj'"]]
# [33953, "'", ['it']]
# [34219, 'W', ["W'itchell"]]
# [34220, "'itchell", []]
# [34254, 'p', ['p.', '174']]
# [34255, '.', ['174']]
# [34382, 'p', ['p.', '499']]
# [34383, '.', ['499']]
# [34415, 'Red-backed', ['Red', '-']]
# [34919, 'A', ['A.', 'Wright']]
# [34920, '.', ['Wright']]
# [35267, 'Fly-catchers', ['Fly', '-']]
# [35290, 'als', ['als j']]
# [35294, 'j', ["saj'S"]]
# [35296, 'saj', ["saj'S"]]
# [35299, "'S", ['of']]
# [35305, 'L', ['L.', 'poiiui-iVtiis']]
# [35306, '.', ['poiiui-iVtiis']]
# [35386, 'L', ['L.', 'nt/us']]
# [35387, '.', ['nt/us']]
# [35578, 'Family-', ['Family']]
# [35586, 'L', ["L ANIID. 'E"]]
# [35588, 'ANIID', []]
# [35593, '.', []]
# [35595, "'E", ['.']]
# [35611, 'Shrikp', ['Shrikp:']]
# [35617, ':', ['.']]
# [35621, 'Laniiis', ['Laniiis,']]
# [35628, ',', ['iin/inna']]
# [35750, 'south-eastern', ['south']]
# [35801, 'north-east', ['north']]
# [36190, 'White-eyes', ['White']]
# [36944, '(Hist', ['(', 'Hist']]
# [36966, 'Vol', ['Vol.']]
# [36969, '.', ['n', ',']]
# [36974, 'p', ['p.', 'i']]
# [36975, '.', ['i', ')']]
# [36977, 'i)', ['i', ')', '.']]
# [37490, 'beaut', ['beaut}-']]
# [37495, '}', [',']]
# [37496, '-', [',', 'they']]
# [37508, 'anj', ["anj'thing"]]
# [37511, "'thing", []]
# [37668, 'Family-', ['Family']]
# [37676, 'AMPEL', ['AMPEL ID. E']]
# [37682, 'ID.', []]
# [37686, 'E', ['.']]
# [37713, 'f;ay>', ['f;ay>///us']]
# [37718, '/', []]
# [37719, '/', []]
# [37720, '/us', [',']]
# [38116, 'Turke}', ["Turke}'"]]
# [38122, "'", [',', 'but']]
# [38663, '1867', ['1867-S']]
# [38667, '-', ['a']]
# [38668, 'S', ['a']]
# [39179, 'rosy-brown', ['rosy']]
# [39213, 'ash-grey', ['ash', '-']]
# [39244, 'tail-coverts', ['tail']]
# [39430, 'wing-coverts', ['wing']]
# [39553, 'wax-like', ['wax', '-']]
# [39764, 'rosy-brown', ['rosy']]
# [39930, 'tail-', ['tail']]
# [40102, 'wax-like', ['wax', '-']]
# [40161, 'tail-feathers', ['tail']]
# [40279, 'breeding-season', ['breeding']]
# [40444, 'cup-shaped', ['cup', '-']]
# [40574, 'hair-lichen', ['hair']]
# [40885, 'breeding-grounds', ['breeding']]
# [40932, 'sea-green', ['sea', '-']]
# [41005, 'pale-olive', ['pale']]
# [41044, 'purplish-grey', ['purplish']]
# [41127, 'brownish-black', ['brownish']]
# [41274, 'greyish-lilac', ['greyish']]
# [41304, 'well-defined', ['well']]
# [41336, 'yellowish-brown', ['yellowish']]
# [41647, 'well-known', ['well']]
# [41670, 'Blue-Tit', ['Blue']]
# [41838, 'largel', ["largel}'"]]
# [41844, '}', [',']]
# [41845, "'", [',', 'if']]
# [41879, 'crane-flies', ['crane']]
# [42015, 'guelder-rose', ['guelder']]
# [42376, 'pleasure-grounds', ['pleasure']]
# [42779, '(in', ['(', 'in']]
# [42932, 'hard-boiled', ['hard']]
# [42950, 'hemp-seed', ['hemp']]
# [42961, 'bread-crumbs', ['bread']]
# [43267, 'bu}', ["bu}'"]]
# [43270, "'", ['au}^']]
# [43661, 'Cage-birds', ['Cage']]
# [43673, 'p', ['p.', '340']]
# [43674, '.', ['340']]
# [43787, 'sponge-cake', ['sponge']]
# [43809, 'hard-boiled', ['hard']]
# [43882, 'soft-skinned', ['soft']]
# [44042, 'captivit3', ['captivit3%']]
# [44051, '%', ['would']]
# [44154, 'certaiul', ['certaiul}-']]
# [44162, '}-', ['not']]
# [44351, 'Subfamil', ["Subfamil}'"]]
# [44359, '}', [',']]
# [44360, "'", [',', 'but']]
# [44861, 'e3', ["e3'^es"]]
# [44863, "'^es", []]
# [44905, 'mostl}', ["mostl}''"]]
# [44911, "'", ['on']]
# [44912, "'", ['on']]
# [45130, 'cup-shaped', ['cup', '-']]
# [45471, 'low-pitched', ['low', '-']]
# [45709, 'Blue-throats', ['Blue']]
# [46257, 'Family-', ['Family']]
# [47152, 'slightl', ["slightl}'"]]
# [47159, '}', ['paler']]
# [47160, "'", ['paler']]
# [47182, 'shaft-streaks', ['shaft']]
# [47270, 'wing-coverts', ['wing']]
# [47322, 'gre3', ["gre3'ish"]]
# [47326, "'ish-wliite", []]
# [47371, 'buff-brownish', ['buff']]
# [47672, 'wing-coverts', ['wing']]
# [47703, 'tail-coverts', ['tail']]
# [47758, 'Flj', ["Flj'catcher"]]
# [47761, "'catcher", []]
# [47936, 'usuall}-placing', ['usuall}-']]
# [48066, 'fruit-tree', ['fruit']]
# [48180, 'trellis-work', ['trellis']]
# [48320, 'ni}', ["ni}'"]]
# [48323, "'", ['collection']]
# [48516, 'fruit-branch', ['fruit']]
# [48694, 'var}', ["var}'"]]
# [48698, "'", ['somewhat']]
# [49028, 'pea-green', ['pea', '-']]
# [49053, 'bluish-white', ['bluish']]
# [49139, 'red-brown', ['red', '-']]
# [49982, 'hazel-nuts', ['hazel']]
# [50143, 'hazel-nuts', ['hazel']]
# [50180, 'egg-', ['egg', '-']]
# [50232, 'sa3', ["sa3'S"]]
# [50235, "'S", [':']]
# [50486, 'awa}', ["awa}'"]]
# [50490, "'", ['.', 'It']]
# [50687, 'call-note', ['call']]
# [50794, 'perching-place', ['perching']]
# [50929, 'call-note', ['call']]
# [50963, 'zt-chick', ['zt', '-', 'chick']]
# [51165, 'zt-chick', ['zt', '-', 'chick']]
# [51420, 'mountain-ash', ['mountain']]
# [52198, 'destro3', ["destro3'ed"]]
# [52205, "'ed", []]
# [52733, 'beech-tree', ['beech']]
# [52852, 'beech-tree', ['beech']]
# [53291, '\\', ["\\\\'a.s"]]
# [53292, '\\', []]
# [53293, "'a.s", []]
# [53304, 'destro3', ["destro3'ed"]]
# [53311, "'ed", [',']]
# [53441, 'awa}', ['awa}-']]
# [53445, '-', [',', 'the']]
# [53572, 'awa}', ["awa}'"]]
# [53576, "'", ['b}^']]
# [53692, 'Fl3', ["Fl3'catcher"]]
# [53695, "'catcher", []]
# [53752, 'egg-', ['egg', '-']]
# [53909, 'successfull3', ["successfull3'"]]
# [53921, "'", ['brought']]
# [53953, '3', ["3'ears"]]
# [53954, "'ears", []]
# [53968, '3', ["3'oung"]]
# [53969, "'oung", []]
# [54181, 'the3', ["the3'"]]
# [54185, "'", ['have']]
# [54287, 'b3', ["b3'"]]
# [54289, "'", ['the']]
# [54373, 'aviar3', ["aviar3'"]]
# [54379, "'", ['life']]
# [54752, 'Family-', ['Family']]
# [54760, 'ML', ["ML 'SCICAPID.F"]]
# [54763, "'SCICAPID.F.", []]
# [54986, 'Fl3', ["Fl3'catcher"]]
# [54989, "'catcher", []]
# [55803, 'partic-', ['partic-↵ularly']]
# [55811, 'ularly', []]
# [56089, 'breeding-plumage', ['breeding']]
# [56636, 'dark-brown', ['dark']]
# [57016, 'nesting-holes', ['nesting']]
# [57257, 'saj', ["saj's"]]
# [57260, "'s", ['that']]
# [57460, 'Red-start', ['Red', '-']]
# [57898, 'ver', ["ver}'"]]
# [57901, '}', ['pale']]
# [57902, "'", ['pale']]
# [58135, 'W', ['W.', 'Warde']]
# [58136, '.', ['Warde']]
# [58248, 'Fl3', ["Fl3'catcher"]]
# [58251, "'catcher", []]
# [58491, 'mountain-side', ['mountain']]
# [58575, 'swiftly-running', ['swiftly']]
# [58610, 'Wood-wren', ['Wood']]
# [58715, 'instinctivel', ["instinctivel}'"]]
# [58727, '}', ['feel']]
# [58728, "'", ['feel']]
# [59326, 'recog-', ['recog-↵nition']]
# [59333, 'nition', []]
# [59816, 'Red-start', ['Red', '-']]
# [60712, 'south-east', ['south']]
# [61207, 'sur-', ['sur-↵prising']]
# [61212, 'prising', []]
# [61314, 'wing-cases', ['wing']]
# [61520, 'etc', ['etc.']]
# [61523, '.', [',', 'become']]
# [61756, 'cage-bird', ['cage']]
# [62061, 'hand-rearing', ['hand']]
# [62252, 'w', ["w'Siy"]]
# [62253, "'Siy", []]
# [62329, 'M', ['M.', 'grisola']]
# [62330, '.', ['grisola']]
# [62384, 'Vol', ['Vol.']]
# [62387, '.', ['I', ',']]
# [62392, 'p', ['p.', '58']]
# [62393, '.', ['58']]
# [62507, 'hard-boiled', ['hard']]
# [62944, 'Fly-catcher', ['Fly', '-']]
# [62999, 'Familv-MUSCICAPID.-E', ['Familv']]
# [63019, '.', ['The']]
# [63026, 'Red-Breasted', ['Red', '-']]
# [63292, 'Ma3', ['Ma3%']]
# [63295, '%', ['and']]
# [63857, 'Vol', ['Vol.']]
# [63860, '.', ['I.']]
# [63862, 'I', ['I.', 'of']]
# [63863, '.', ['of']]
# [64038, 'January', ["January'"]]
# [64045, "'", ['24th']]
# [64295, 'Berwick-on-Tweed', ['Berwick-']]
# [64386, 'light-ship', ['light']]
# [64542, 'H', ['H.', 'Guruey']]
# [64543, '.', ['Guruey']]
# [64572, 'p', ['p.', '136']]
# [64573, '.', ['136']]
# [64612, 'Red-breasted', ['Red', '-']]
# [64625, 'Fly-catcher', ['Fly', '-']]
# [65419, '(taking', ['(', 'taking']]
# [65657, 'connecting-link', ['connecting']]
# [65821, '\'"', ["'", '"', 'The']]
# [65827, 'Red-breasted', ['Red', '-']]
# [65959, 'bluish-grey', ['bluish']]
# [65972, 'olive-brown', ['olive']]
# [65994, 'tail-feathers', ['tail']]
# [66008, 'blackish-brown', ['blackish']]
# [66079, 'blackish-brown', ['blackish']]
# [66114, 'orange-chestnut', ['orange']]
# [66191, 'tail-coverts', ['tail']]
# [66370, 'orange-chestnut', ['orange']]
# [66422, 'bluish-grey', ['bluish']]
# [66588, 'M', ['M.', 'mituita']]
# [66589, '.', ['mituita']]
# [66805, '{M.', ['{', 'M.']]
# [67149, 'distinc-', ['distinc-↵tive']]
# [67158, 'tive', []]
# [67322, 'breeding-plumage', ['breeding']]
# [67342, 'Q', ['Q.', 'ri<sst']]
# [67343, '.', ['ri<sst']]
# [67491, 'P', ['P.', 'capiiata']]
# [67492, '.', ['capiiata']]
# [67551, 'forest-haunting', ['forest']]
# [67612, 'beech-woods', ['beech']]
# [67800, 'alarm-note', ['alarm']]
# [67820, 'p', ["p'nik"]]
# [67821, "'nik", []]
# [67895, 'call-note', ['call']]
# [67960, "'", ["''", 'fnid']]
# [67961, "'", ['fnid']]
# [68049, "'", ["''", 'plnvick']]
# [68050, "'", ['plnvick']]
# [68059, '"', ['"\'', 'or']]
# [68060, "'", ['or']]
# [68190, 'bird-notes', ['bird']]
# [68207, 'A', ['A.', 'Walter']]
# [68208, '.', ['Walter']]
# [68350, 'Red-breasted', ['Red', '-']]
# [68585, 'beech-tree', ['beech']]
# [68882, 'bluish-green', ['bluish']]
# [68934, 'rusty-brown', ['rusty']]
# [68992, 'ground-colour', ['ground']]
# [69016, 'greyish-brown', ['greyish']]
# [69030, 'shell-markings', ['shell']]
# [69294, 'cage-bird', ['cage']]
# [69570, 'house-fly', ['house']]
# [70731, 'Vol', ['Vol.']]
# [70734, '.', ['I', ',']]
# [70739, 'p', ['p.', '458']]
# [70740, '.', ['458']]
# [71031, 'Hirujidinida', ['Hirujidinida:']]
# [71043, ':', ['constitute']]
# [71608, 'cage-birds', ['cage']]
# [71677, 'over-feeding', ['over']]
# [71713, 'FamUy-IIIRUXDINID', ['FamUy']]
# [71732, 'E', ['.']]
# [72610, 'prussian-blue', ['prussian']]
# [72684, 'bluish-green', ['bluish']]
# [72738, 'wing-covert', ['wing']]
# [72750, 'greyish-', ['greyish']]
# [72775, 'tail-feathers', ['tail']]
# [72914, 'prussian-blue', ['prussian']]
# [72954, 'wing-coverts', ['wing']]
# [73167, 'breast-belt', ['breast']]
# [73532, 'House-', ['House']]
# [73543, 'Sand-Martins', ['Sand']]
# [73602, 'out-house', ['out', '-']]
# [73795, 'House-Martin', ['House']]
# [73867, 'Sand-Martins', ['Sand']]
# [73892, 'sand-bank', ['sand']]
# [74166, 'out-houses', ['out', '-']]
# [74178, 'boat-houses', ['boat']]
# [74251, 'half-', ['half']]
# [74261, 'quarter-cup', ['quarter']]
# [74335, 'chimne3', ["chimne3's"]]
# [74342, "'s", [',']]
# [74570, 's3', ["s3'camore"]]
# [74572, "'camore", []]
# [74802, 'nesting-sites', ['nesting']]
# [74881, 'mud-pellets', ['mud', '-']]
# [74911, 'ha}', ["ha}'"]]
# [74914, "'", [',', 'or']]
# [74955, 'grass-stems', ['grass']]
# [74993, 'b', ["b}'"]]
# [74994, '}', ['a']]
# [74995, "'", ['a']]
# [75191, 'ground-colour', ['ground']]
# [75386, 'lavender-grey', ['lavender']]
# [75400, 'shell-spots', ['shell']]
# [75719, 'well-formed', ['well']]
# [75877, '3', ["3'oung"]]
# [75878, "'oung", []]
# [76861, 'melod', ["melod}'"]]
# [76866, '}', ['from']]
# [76867, "'", ['from']]
# [76897, 'railway-station', ['railway']]
# [77046, 'ver', ["ver}'"]]
# [77049, '}', ['varied']]
# [77050, "'", ['varied']]
# [77219, 'lnvit-(it-tit-(il', ['lnvit']]
# [77272, 'largel', ["largel}'"]]
# [77278, '}', ['of']]
# [77279, "'", ['of']]
# [77400, 'dung-beetles', ['dung']]
# [77858, 'cage-bird', ['cage']]
# [78663, 'aviar}', ['aviar}-']]
# [78669, '-', [',', 'where']]
# [78711, 'Familx-HIR', ['Familx']]
# [78722, 'UNDINID', []]
# [78729, '.', []]
# [78731, '-', ['.']]
# [78732, 'E', ['.']]
# [78736, '"', ['"FiiK']]
# [78737, 'FiiK', []]
# [78742, 'RivD-RuMPKi', ['RivD']]
# [78753, ')', ['Swallow']]
# [78857, 'Family-', ['Family']]
# [78865, 'HI', ['HI R UNDINID. E']]
# [78868, 'R', []]
# [78870, 'UNDINID', []]
# [78879, 'E', ['.']]
# [78924, 'House-Martin', ['House']]
# [79017, 'sa3', ["sa3's"]]
# [79020, "'s", ['of']]
# [79115, 'North-west', ['North']]
# [79589, 'blue-black', ['blue']]
# [79618, 'tail-coverts', ['tail']]
# [79676, 'brownish-black', ['brownish']]
# [79740, 'horu-yellowish', ['horu']]
# [79890, 'smok', ['smok\\-']]
# [79894, '\\--brown', ['-', 'brown']]
# [80153, 'b}', ["b}'"]]
# [80155, "'", ['the']]
# [80779, 'certainl', ["certainl}'"]]
# [80787, '}', ['can']]
# [80788, "'", ['can']]
# [80960, 'call-note', ['call']]
# [81071, 'House-', ['House']]
# [81248, 'railway-', ['railway']]
# [81364, 'semi-circular', ['semi']]
# [81381, 'denii-semi-circular', ['denii']]
# [81645, 'table-knife', ['table']]
# [81999, 'the', ["the}'"]]
# [82002, '}', ['are']]
# [82003, "'", ['are']]
# [82078, 'ros', ["ros}'"]]
# [82081, '}', ['when']]
# [82082, "'", ['when']]
# [82089, 'fresh-laid', ['fresh']]
# [82587, 'ha}', ["ha}'"]]
# [82590, "'", ['and']]
# [82769, 'ha}-to', ['ha}-']]
# [83089, 'Jul}', ["Jul}'"]]
# [83093, "'", [',', '1891']]
# [83120, '\\V.', ['\\V', '.']]
# [83124, 'R', ['R.', 'Ogilvie']]
# [83125, '.', ['Ogilvie']]
# [83165, 'House-AIartins', ['House']]
# [83297, 'j', ["j'ouug"]]
# [83298, "'ouug", []]
# [83326, 'rump-steak', ['rump']]
# [83753, 'da}', ["da}'"]]
# [83756, "'", ['they']]
# [83945, 'cocoa-nut', ['cocoa']]
# [84168, 'Hinindinida', ['Hinindinida:']]
# [84179, ':', ['when']]
# [85349, 'cage-birds', ['cage']]
# [85365, 'cupboard-love', ['cupboard']]
# [85903, 'cocoa-nut', ['cocoa']]
# [86177, 'cage-door', ['cage']]
# [86299, "don't", ['do', "n't"]]
# [86362, 'House-', ['House']]
# [86398, 'acutel', ["acutel}'"]]
# [86404, '}', [':']]
# [86405, "'", [':']]
# [86464, 'cage-bird', ['cage']]
# [86659, 'well-warmed', ['well']]
# [86721, '1-amily-IIIR', ['1-amily']]
# [86734, 'UNDL', []]
# [86738, '\\', []]
# [86740, 'ID.E', []]
# [86751, 'Sand-Martin', ['Sand']]
# [86765, 'Col', ['Col ill']]
# [86769, 'ill', []]
# [86784, 'LiN', ["LiN'N"]]
# [86787, "'N", ['.']]
# [86913, 'Sand-Martin', ['Sand']]
# [87469, 'South-eastern', ['South']]
# [87508, 'Occasionallj', ["Occasionallj'"]]
# [87520, "'", ['it']]
# [87771, 'Sand-Martin', ['Sand']]
# [87803, 'mouse-brown', ['mouse']]
# [87888, 'blackish-brown', ['blackish']]
# [88340, 'Sand-lMartin', ['Sand']]
# [88585, 'sea-shore', ['sea', '-']]
# [88613, 'railway-cutting', ['railway']]
# [88632, 'road-side', ['road']]
# [88670, 'sand-', ['sand']]
# [88679, 'gravel-pit', ['gravel']]
# [88696, 'brick-earth', ['brick']]
# [88760, 'half-rotten', ['half']]
# [88843, 'Sand-Martin', ['Sand']]
# [89099, 'flint-stone', ['flint']]
# [89575, 'Sand-Martin', ['Sand']]
# [89976, 'neatl', ["neatl}'"]]
# [89981, '}', ['arranged']]
# [89982, "'", ['arranged']]
# [90125, 'carefully-removed', ['carefully']]
# [90209, 'pinky-white', ['pinky']]
# [90259, 'flower-like', ['flower']]
# [90289, 'ver', ["ver}'"]]
# [90292, '}', ['slight']]
# [90293, "'", ['slight']]
# [90444, 'Sand-', ['Sand']]
# [90519, 'man', ["man}'"]]
# [90522, '}', ['cabinet']]
# [90523, "'", ['cabinet']]
# [90681, 'best-formed', ['best']]
# [90835, 'gloss', ['gloss}-']]
# [90840, '}', [',']]
# [90841, '-', [',', 'and']]
# [90953, 'Sand-Martins', ['Sand']]
# [91010, 'birds', ["birds'"]]
# [91015, "'-nester", ['-', 'nester']]
# [91094, 'ever}-year', ['ever}-']]
# [91360, 'land-slip', ['land']]
# [91377, 'temporar}', ["temporar}'"]]
# [91386, "'", ['block']]
# [91520, 'Sand-', ['Sand']]
# [91583, 'frequentl}', ["frequentl}'"]]
# [91593, "'", ['be']]
# [91921, 'call-note', ['call']]
# [92066, 'vaguel', ["vaguel}'"]]
# [92072, '}', ['resembling']]
# [92073, "'", ['resembling']]
# [92110, 'Reed-Warbler', ['Reed']]
# [92128, 'usuall', ["usuall}'"]]
# [92134, '}', ['uttered']]
# [92135, "'", ['uttered']]
# [92399, 'wide-open', ['wide']]
# [92475, '3', ["3'oung"]]
# [92476, "'oung", []]
# [92508, 'dragon-flies', ['dragon']]
# [92650, 'b', ["b}'"]]
# [92651, '}', ['such']]
# [92652, "'", ['such']]
# [92841, 'dragon-fly', ['dragon']]
# [92865, 'Sand-Martin', ['Sand']]
# [93145, 'cage-bird', ['cage']]
# [93159, 'Sand-Martin', ['Sand']]
# [93273, 'Sand-Martius', ['Sand']]
# [93328, 'j', ["j'oiing"]]
# [93329, "'oiing", []]
# [94323, 'food-pot', ['food']]
# [94377, 'half-au-hour', ['half']]
# [95031, 'Sand-Martius', ['Sand']]
# [95116, 'famil', ["famil}'"]]
# [95121, '}', ['consists']]
# [95122, "'", ['consists']]
# [95148, 'hard-billed', ['hard']]
# [95169, 'seed-eatiug', ['seed']]
# [95205, '011I3', ["011I3'"]]
# [95210, "'", ['distinguishes']]
# [95243, 'fFrin^HluurJ', ['f', 'Frin^Hluur']]
# [95270, 'E>i!beyiziHaJ', ['E>i!beyiziHa']]
# [95793, 'F)', ["F) hio'iUidcr"]]
# [95796, 'hio', []]
# [95799, "'iUidcr", []]
# [95846, 'well-developed', ['well']]
# [95862, 'con-', ['con-↵cealed']]
# [95867, 'cealed', []]
# [95951, 'non-existent', ['non', '-']]
# [96125, 'partially-', ['partially']]
# [96587, 'eye-socket', ['eye', '-']]
# [96605, 'R', ['R.', 'B.']]
# [96606, '.', ['B.']]
# [96608, 'B', ['B.', 'Sharpe']]
# [96609, '.', ['Sharpe']]
# [96631, 'Vol', ['Vol.']]
# [96634, '.', ['XII']]
# [96826, 'ver', ["ver}'"]]
# [96829, '}', ['feebly']]
# [96830, "'", ['feebly']]
# [96970, 'eye-socket', ['eye', '-']]
# [96987, 'E»ib€risi', ['E»ib€risi)ur']]
# [96996, ')ur', [',']]
# [97040, 'ma}', ["ma}'"]]
# [97043, "'", ['be']]
# [97075, 'well-marked', ['well']]
# [97173, 'complete!', ["complete!}'"]]
# [97182, '}', ['closing']]
# [97183, "'", ['closing']]
# [97434, 'the', ["the}'"]]
# [97437, '}', ['approach']]
# [97438, "'", ['approach']]
# [97581, 'cage-birds', ['cage']]
# [97663, 'Family-FRIKGILLID', ['Family']]
# [97681, "'E", ['.']]
# [97686, 'Subfamily-', ['Subfamily']]
# [97697, 'COCCOTHRAUSTIN', ['COCCOTHRAUSTIN/E']]
# [97711, '/E', ['.']]
# [97860, 'generall}', ['generall}-']]
# [97869, '-', [';', 'the']]
# [97973, 'North-western', ['North']]
# [98034, 'well-known', ['well']]
# [98220, 'B', ['B.', 'Kinnear']]
# [98221, '.', ['Kinnear']]
# [98668, 'yellowish-olive', ['yellowish']]
# [98796, 'greyish-', ['greyish']]
# [99014, 'ear-coverts', ['ear', '-']]
# [99172, 'flesh-coloured', ['flesh']]
# [99218, 'horn-brown', ['horn']]
# [99382, 'shaft-streaks', ['shaft']]
# [99498, '3', ["3'ellow"]]
# [99499, "'ellow", []]
# [100107, 'stubble-fields', ['stubble']]
# [100143, 'Except-', ['Except-↵ing']]
# [100151, 'ing', []]
# [100220, 'alwaj', ["alwaj's"]]
# [100225, "'s", ['bright']]
# [100426, 'zshwee>', ['zshwee>-']]
# [100433, '-', [',', 'and']]
# [100488, 'call-note', ['call']]
# [100555, 'resemb-', ['resemb-↵ling']]
# [100563, 'ling', []]
# [101035, 'furze-bushes', ['furze']]
# [101157, 'spruce-firs', ['spruce']]
# [101692, 'occasionally', ["occasionally'"]]
# [101704, "'", ['loosely']]
# [102079, 'half-decayed', ['half']]
# [102142, 'root-fibre', ['root']]
# [102179, 'grass-straws', ['grass']]
# [102265, 'horse-hairs', ['horse']]
# [102397, 'horse-hairs', ['horse']]
# [102567, 'horse-hairs', ['horse']]
# [102689, '7.-', ['7', '.', '- -']]
# [102693, '-', ['Loosely']]
# [103135, 'oak-twigs', ['oak', '-']]
# [103243, 'ground-tint', ['ground']]
# [103272, 'pinkish-white', ['pinkish']]
# [103361, 'chief!', ["chief!}'"]]
# [103367, '}', ['confined']]
# [103368, "'", ['confined']]
# [103420, 'comma-', ['comma']]
# [103460, 'occasionall', ["occasionall}'"]]
# [103471, '}', [',']]
# [103472, "'", [',', 'and']]
# [103573, 'sienna-reddish', ['sienna']]
# [103592, 'reddish-chocolate', ['reddish']]
# [103641, 'principall', ["principall}'"]]
# [103651, '}', ['confined']]
# [103652, "'", ['confined']]
# [103748, 'fl_v-marks', ['fl_v']]
# [103877, 'ma}', ["ma}'"]]
# [103880, "'", ['be']]
# [103930, 'spindle-shaped', ['spindle']]
# [104167, 'well-known', ['well']]
# [104429, 'breeding-season', ['breeding']]
# [105221, 'nest-box', ['nest']]
# [105548, 'cage-trap', ['cage']]
# [106233, 'Green-finch', ['Green']]
# [106582, 'Family^', ['Family']]
# [106590, 'FRINGILLID', ["FRINGILLID.'E"]]
# [106601, "'E", ['.']]
# [106606, 'Subfamily-', ['Subfamily']]
# [106617, 'COCCOTIIRA', ['COCCOTIIRA USTIN/E']]
# [106628, 'USTIN', []]
# [106633, '/E', ['.']]
# [107230, 'Aft}', ["Aft}'"]]
# [107234, "'", ['3-ears']]
# [107288, 'market-gardens', ['market']]
# [107756, 'ciunamon-brown', ['ciunamon']]
# [107986, 'tail-coverts', ['tail']]
# [108007, 'bluish-black', ['bluish']]
# [108186, 'tail-coverts', ['tail']]
# [108199, 'cinnamon-brown', ['cinnamon']]
# [108266, 'extremit', ["extremit}'"]]
# [108274, '}', ['of']]
# [108275, "'", ['of']]
# [108324, 'Dove-brown', ['Dove']]
# [108365, 'tail-coverts', ['tail']]
# [108395, 'bluish-grey', ['bluish']]
# [108447, 'ilesh-coloured', ['ilesh']]
# [108469, 'flesh-coloured', ['flesh']]
# [108571, '3', ["3'Oung"]]
# [108572, "'Oung", []]
# [109065, 'ver', ['ver}?']]
# [109068, '}', ['moderate']]
# [109069, '?', ['moderate']]
# [109203, 'call-note', ['call']]
# [109349, 'Greenfinch-like', ['Greenfinch']]
# [109399, 'call-note', ['call']]
# [109426, 'cr}', ["cr}'"]]
# [109429, "'", ['of']]
# [109458, 'ver', ["ver}'"]]
# [109461, '}', ['inferior']]
# [109462, "'", ['inferior']]
# [109576, 'well-wooded', ['well']]
# [109608, 'forest-clearings', ['forest']]
# [109706, '3', ["3'ews"]]
# [109707, "'ews", []]
# [109933, 'usuall', ['usuall}^']]
# [109939, '}^', ['makes']]
# [109992, 'blackberry-vines', ['blackberry']]
# [110018, 'holl', ["holl}'"]]
# [110022, '}', [',']]
# [110023, "'", [',', 'or']]
# [110061, 'beech-tree', ['beech']]
# [110145, 'lichen-covered', ['lichen']]
# [110169, 'pear-tree', ['pear']]
# [110795, 'Wood-Pigeon', ['Wood']]
# [110984, 'bufl&sh-green', ['bufl&sh']]
# [111049, 'Common-', ['Common']]
# [111061, 'Reed-', ['Reed']]
# [111129, 'pitch-brown', ['pitch']]
# [111167, 'lilaciue-gre', ['lilaciue']]
# [111179, '}', [':']]
# [111180, "'", [':']]
# [111224, 'closel', ["closel}'"]]
# [111230, '}', ['with']]
# [111231, "'", ['with']]
# [111744, '3', ["3'ear"]]
# [111745, "'ear", []]
# [111756, 'cherr^', ["cherr^'"]]
# [111762, "'-kernels", ['-kernels']]
# [111773, 'beech-mast', ['beech']]
# [111785, 'yew-berries', ['yew', '-']]
# [111833, 'sunflower-seeds', ['sunflower']]
# [111862, 'beech-nuts', ['beech']]
# [111874, 'canar}', ['canar}-']]
# [111880, '-', [',', 'and']]
# [111974, 'cage-bird', ['cage']]
# [112623, 'hand-', ['hand']]
# [112783, 'meal-worms', ['meal']]
# [112798, 'house-flies', ['house']]
# [113097, 'prison-diet', ['prison']]
# [113167, 'Black-tailed', ['Black']]
# [113376, 'an}', ["an}'"]]
# [113379, "'", ['species']]
# [113426, 'full', ["full}'"]]
# [113430, '}', ['as']]
# [113431, "'", ['as']]
# [113549, 'Rev', ['Rev.']]
# [113552, '.', ['H.']]
# [113554, 'H', ['H.', 'A.']]
# [113555, '.', ['A.']]
# [113557, 'A', ['A.', 'Alacpherson']]
# [113558, '.', ['Alacpherson']]
# [113654, 'wholl', ["wholl}'"]]
# [113659, '}', ['destitute']]
# [113660, "'", ['destitute']]
# [113689, 'facult', ["facult}'"]]
# [113695, '}', ['.']]
# [113696, "'", ['.', 'In']]
# [113702, 'ni}', ["ni}'"]]
# [113705, "'", ['friend']]
# [113731, 'A', ['A.', 'Witchell']]
# [113732, '.', ['Witchell']]
# [113784, 'Bird-song', ['Bird']]
# [113806, 'p', ['p.', '172']]
# [113807, '.', ['172']]
# [113889, 'Rev', ['Rev.']]
# [113892, '.', ['H.']]
# [113894, 'H', ['H.', 'A.']]
# [113895, '.', ['A.']]
# [113897, 'A', ['A.', 'Macpherson']]
# [113898, '.', ['Macpherson']]
# [114160, 'Home3', ["Home3'er"]]
# [114165, "'er", []]
# [114195, 'Vol', ['Vol.']]
# [114198, '.', ['XX']]
# [114204, 'p', ['p.', '4S9']]
# [114205, '.', ['4S9']]
# [114216, 'cherry-kernel', ['cherry']]
# [114386, 'so-called', ['so', '-', 'called']]
# [114577, 'slender-billed', ['slender']]
# [114888, 'au}', ["au}'"]]
# [114891, "'", ['other']]
# [114937, 'I^ri', ['I^ri)ioi/ln']]
# [114941, ')ioi/ln', []]
# [115170, 'Family-', ['Family']]
# [115193, 'Subfamily-', ['Subfamily']]
# [115223, 'Two-Barred', ['Two', '-']]
# [115265, 'C', ['C.', 'L.']]
# [115266, '.', ['L.']]
# [115268, 'L', ['L.', 'Brkhm']]
# [115269, '.', ['Brkhm']]
# [115427, ':-', [':', '-', 'It']]
# [115831, 'co', ['co.']]
# [115833, '.', ['Dublin']]
# [116172, 'H', ['H.', "Doubleda}'"]]
# [116173, '.', ["Doubleda}'"]]
# [116175, 'Doubleda', ["Doubleda}'"]]
# [116183, '}', ['shot']]
# [116184, "'", ['shot']]
# [116290, '(Manual', ['(', 'Manual']]
# [116316, 'p', ['p.', '195']]
# [116317, '.', ['195']]
# [116319, '195.', ['195', '.']]
# [116478, 'rose-madder', ['rose']]
# [116750, 'brownish-black', ['brownish']]
# [116771, 'rosy-white', ['rosy']]
# [116820, 'rose-madder', ['rose']]
# [116848, 'bell', ["bell}'"]]
# [116852, '}', [',']]
# [116853, "'", [',', 'becoming']]
# [116909, 'horn-brown', ['horn']]
# [116954, 'greenish-grey', ['greenish']]
# [117254, 'tail-feathers', ['tail']]
# [117273, 'well-defined', ['well']]
# [117286, 'greenish-', ['greenish']]
# [117361, 'White-winged', ['White']]
# [117374, 'Crossbill"', ['Crossbill']]
# [117687, 'the', ["the}'"]]
# [117690, '}', ['see']]
# [117691, "'", ['see']]
# [117751, 'Rose-finches', ['Rose']]
# [118439, 'L', ['L.', 'curvirostra']]
# [118440, '.', ['curvirostra']]
# [118849, 'Vol', ['Vol.']]
# [118852, '.', ['XX']]
# [118858, 'p', ['p.', '396']]
# [118859, '.', ['396']]
# [118890, 'cage-birds', ['cage']]
# [119154, 'scarlet-red', ['scarlet']]
# [119403, 'grey-', ['grey']]
# [119413, 'black-striped', ['black']]
# [119689, 'Family-', ['Family']]
# [119712, 'Subfamily-', ['Subfamily']]
# [119767, 'iUi', ["iUi'7'iyosira"]]
# [119770, "'7", []]
# [119772, "'iyosira", []]
# [119806, 'R', ['R.', 'Bowdler']]
# [119807, '.', ['Bowdler']]
# [120002, 'principall', ["principall}'"]]
# [120012, '}', ['confined']]
# [120013, "'", ['confined']]
# [120402, 'Two-barred', ['Two', '-']]
# [120493, 'wing-coverts', ['wing']]
# [120677, 'positively', ["positively'"]]
# [120687, "'", [':']]
# [121101, 'insect-food', ['insect']]
# [122085, 'earh', ["earh'"]]
# [122089, "'", ['breeders']]
# [122192, 'May;', ['May', ';']]
# [122445, 'faniilj^-part}^', ['faniilj^']]
# [122529, 'family-part', ['family']]
# [122540, '}', ["the}'"]]
# [122541, '^', ["the}'"]]
# [122543, 'the', ["the}'"]]
# [122546, '}', ['appear']]
# [122547, "'", ['appear']]
# [122777, 'mouutain-ash', ['mouutain']]
# [123105, 'Willow-', ['Willow']]
# [123397, '(Hist', ['(', 'Hist']]
# [123419, 'Vol', ['Vol.']]
# [123422, '.', ['II']]
# [123428, 'pp', ['pp.']]
# [123430, '.', ['32']]
# [123432, '32-33', ['32', '-', '33']]
# [123549, 'so-called', ['so', '-', 'called']]
# [123561, 'Pine-Grosbeak', ['Pine']]
# [123824, 'call-note', ['call']]
# [124779, 'cup-shaped', ['cup', '-']]
# [124932, 'fri', ['fri)m']]
# [124935, ')m', ['four']]
# [124956, 'rarely-', ['rarely']]
# [124978, 'the', ["the}'"]]
# [124981, '}', ['var_v']]
# [124982, "'", ['var_v']]
# [125008, 'greenish-blue', ['greenish']]
# [125025, 'gre_vish-white', ['gre_vish']]
# [125103, 'dai-k-brown', ['dai-k']]
# [125158, 'reddish-brown', ['reddish']]
# [125289, 'A', ['A.', 'B.']]
# [125290, '.', ['B.']]
# [125292, 'B', ['B.', 'Farn']]
# [125293, '.', ['Farn']]
# [125329, '3', ["3'oung"]]
# [125330, "'oung", []]
# [125356, 'largel', ["largel}'"]]
# [125362, '}', ['upon']]
# [125363, "'", ['upon']]
# [125485, 'fir-', ['fir', '-']]
# [125494, 'pine-cones', ['pine']]
# [125552, 'man-', ['man-↵dibles']]
# [125557, 'dibles', []]
# [125785, 'onl', ["onl}'"]]
# [125788, '}', ['the']]
# [125789, "'", ['the']]
# [125894, 'nn', ["nn'"]]
# [125896, "'", ['possession']]
# [125985, 'Vol', ['Vol.']]
# [125988, '.', ['I', ',']]
# [125997, '205-6', ['205', '-']]
# [126057, 'ver', ['ver\\-']]
# [126060, '\\-', ['tame']]
# [126118, 'bnsil', ["bnsil}'"]]
# [126123, '}', ['emploj-ed']]
# [126124, "'", ['emploj-ed']]
# [126165, 'snow-laden', ['snow']]
# [126176, 'fir-tree', ['fir', '-']]
# [126624, 'fir-seeds', ['fir', '-']]
# [126708, 'hemp-seed', ['hemp']]
# [126797, 'ver', ["ver}'"]]
# [126800, '}', ['fond']]
# [126801, "'", ['fond']]
# [126957, 'cage-bird', ['cage']]
# [127193, 'cock-bird', ['cock']]
# [127500, 'cock-bird', ['cock']]
# [128059, 'chip-chip-i/iip', ['chip']]
# [128270, 'apple-pips', ['apple']]
# [128320, 'sunflower-seed', ['sunflower']]
# [128449, 'wooden-framed', ['wooden']]
# [128463, 'flight-cage', ['flight']]
# [128567, 'cock-bird', ['cock']]
# [128622, 'carefull', ["carefull}'"]]
# [128630, '}', ['shutting']]
# [128631, "'", ['shutting']]
# [128805, 'three-quarters', ['three']]
# [129040, 'prison-breaker', ['prison']]
# [129086, 'cock-bird', ['cock']]
# [129428, 'Family-', ['Family']]
# [129461, '-FR', ['-', 'FR I Mj 11. LLWE']]
# [129465, 'I', []]
# [129467, 'Mj', []]
# [129470, '11', []]
# [129472, '.', []]
# [129474, 'LLWE', []]
# [129485, 'Pink-Grosbeak', ['Pink']]
# [129501, 'Pyy', ['Pyy)linla']]
# [129504, ')linla', []]
# [129702, '(4th', ['(', '4th']]
# [129707, 'Ed', ['Ed.']]
# [129709, '.', ['Yarrell']]
# [129721, 'B', ['B.', 'B.']]
# [129722, '.', ['B.']]
# [130146, 'confine-', ['confine-↵ment']]
# [130155, 'ment', []]
# [130184, 'oul', ['oul}-']]
# [130187, '}-', ['imported']]
# [130222, 'cage-bird', ['cage']]
# [130275, 'Jul', ["Jul}'"]]
# [130278, '}', ['1896']]
# [130279, "'", ['1896']]
# [130517, 'insect-eating', ['insect']]
# [130601, 'sunflower-seed', ['sunflower']]
# [130703, 'aviar', ["aviar}'"]]
# [130708, '}', ['consisted']]
# [130709, "'", ['consisted']]
# [130918, 'H', ['H.', 'St.']]
# [130919, '.', ['St.']]
# [130921, 'St', ['St.']]
# [130923, '.', ['Quintin']]
# [130969, 'sec', ['sec.']]
# [130972, '.', ['Vol.']]
# [130974, 'Vol', ['Vol.']]
# [130977, '.', ['V', ',']]
# [130982, 'PP-', ['PP- .']]
# [130986, '.55-56', ['55', '-']]
# [131001, 'Family-', ['Family']]
# [131024, 'Subfamily-', ['Subfamily']]
# [131066, 'Py}', ['Py})hula']]
# [131069, ')hula', []]
# [131093, 'DR', ['DR.']]
# [131095, '.', ['SHARPB']]
# [131421, 'pyrrhulay', ['pyrrhula']]
# [131876, 'well-wooded', ['well']]
# [131987, 'e3', ["e3'e"]]
# [131989, "'e", ['and']]
# [132048, 'blue-black', ['blue']]
# [132088, 'ash-grey', ['ash', '-']]
# [132127, 'wing-coverts', ['wing']]
# [132456, 'salmon-red', ['salmon']]
# [132487, 'tail-coverts', ['tail']]
# [132701, 'Dove-brown', ['Dove']]
# [132806, 'wing-bar', ['wing']]
# [132973, 'orange-vermilion', ['orange']]
# [133365, 'chief!', ["chief!}'"]]
# [133371, '}', ['haunts']]
# [133372, "'", ['haunts']]
# [133650, 'frequentl}', ['frequentl}"']]
# [133660, '"', ['lanes']]
# [133804, 'hazel-hedge', ['hazel']]
# [133878, 'b', ["b}'"]]
# [133879, '}', ['a']]
# [133880, "'", ['a']]
# [133976, 'spruce-fir', ['spruce']]
# [134058, 'blackberr', ["blackberr}'"]]
# [134067, '}', ['vines']]
# [134068, "'", ['vines']]
# [134123, 'elm-foliage', ['elm', '-']]
# [134178, 'box-tree', ['box', '-']]
# [134471, 'root-fibre', ['root']]
# [134492, 'horse-hairs', ['horse']]
# [134813, 'blackish-brown', ['blackish']]
# [134871, 'red-brown', ['red', '-']]
# [135033, 'rarel', ["rarel}'"]]
# [135038, '}', ['the']]
# [135039, "'", ['the']]
# [135186, 'chocolate-brown', ['chocolate']]
# [135429, 'fruit-grower', ['fruit']]
# [136246, 'yew-tree', ['yew', '-']]
# [136352, 'da}', ["da}'"]]
# [136355, "'", [':']]
# [136555, 'Jew', ["Jew's"]]
# [136558, "'s-harp", ['-']]
# [136573, 'hand-reared', ['hand']]
# [136615, 'musical-box', ['musical']]
# [136681, 'call-note', ['call']]
# [137115, 'par-ticularl', ["par-↵ticularl}'"]]
# [137128, '}', ['of']]
# [137129, "'", ['of']]
# [137134, 'fruit-trees', ['fruit']]
# [137276, "sj'stematicall", ["sj'stematicall}'"]]
# [137290, '}', ['.']]
# [137291, "'", ['.', 'Attempts']]
# [137327, 'well-meaning', ['well']]
# [137514, 'fruit-grower', ['fruit']]
# [137687, 'captivit}', ["captivit}'"]]
# [137696, "'", [',', 'and']]
# [138041, '3', ["3'ear"]]
# [138042, "'ear", []]
# [138102, 'plum-', ['plum']]
# [138109, 'apple-', ['apple']]
# [138121, 'pear-trees', ['pear']]
# [138156, 'gooseberry-', ['gooseberry']]
# [138172, 'currant-bushes', ['currant']]
# [138323, 'flower-buds', ['flower']]
# [138372, 'b', ["b}'", '.']]
# [138373, '}', ['.']]
# [138374, "'", ['.', 'This']]
# [139039, '3', ["3'ou"]]
# [139040, "'ou", []]
# [139244, 'fruit-trees', ['fruit']]
# [139308, 'thereb', ["thereb\\'"]]
# [139314, '\\', ['.']]
# [139315, "'", ['.', 'If']]
# [139350, 'cage-trap', ['cage']]
# [139422, 'cage-birds', ['cage']]
# [139435, 'the', ["the}'"]]
# [139438, '}', ['would']]
# [139439, "'", ['would']]
# [139696, 'hand-reared', ['hand']]
# [140242, 'sunflower-seeds', ['sunflower']]
# [140409, '-^FRINGIL', ['-', '^FRINGIL L ID. F']]
# [140419, 'L', []]
# [140421, 'ID.', []]
# [140425, 'F', ['.']]
# [140429, 'Subfamily-', ['Subfamily']]
# [140440, 'FR', ['FR I XG I L L INAl']]
# [140443, 'I', []]
# [140445, 'XG', []]
# [140448, 'I', []]
# [140450, 'L', []]
# [140452, 'L', []]
# [140454, 'INAl', []]
# [140473, 'Rose-Finch', ['Rose']]
# [141208, 'Family-', ['Family']]
# [141216, 'FRINGILLID', ["FRINGILLID.'E"]]
# [141227, "'E", ['.']]
# [141232, 'Subfamily-', ['Subfamily']]
# [141243, 'FRINGILLIN.F.', ['FRINGILLIN.F']]
# [141297, 'DR', ['DR.']]
# [141299, '.', ['SHARPE']]
# [141503, 'occasion-ally', ['occasion']]
# [141721, 'well-known', ['well']]
# [141762, 'cage-bird', ['cage']]
# [141874, 'ma}', ["ma}'"]]
# [141877, "'", ['have']]
# [142132, 'bird-catchers', ['bird']]
# [142153, 'Swaj', ["Swaj'sland"]]
# [142157, "'sland", []]
# [142657, 'Rose-finch', ['Rose']]
# [142757, 'cage-birds', ['cage']]
# [142845, 'sub-species', ['sub', '-']]
# [142917, 'under-parts', ['under']]
# [142956, 'tail-coverts', ['tail']]
# [143085, 'tail-feathers', ['tail']]
# [143109, 'olive-brown', ['olive']]
# [143171, 'wing-coverts', ['wing']]
# [143243, 'horn-brown', ['horn']]
# [143485, 'ver', ["ver}'"]]
# [143488, '}', ['little']]
# [143489, "'", ['little']]
# [143498, '3', ["3'ellow"]]
# [143499, "'ellow", []]
# [143984, 'Slcswick-Holstein', ['Slcswick']]
# [144013, 'how-', ['how', '-']]
# [144404, 'hill', ["hill}'"]]
# [144408, '}', [',']]
# [144409, "'", [',', 'cultivated']]
# [144502, 'fruit-', ['fruit']]
# [144513, 'walnut-trees', ['walnut']]
# [144670, 'p', ['p.', '59']]
# [144671, '.', ['59']]
# [144830, 'Vol', ['Vol.']]
# [144833, '.', ['II']]
# [144839, 'p', ['p.', '85']]
# [144840, '.', ['85']]
# [144939, 'pine-', ['pine']]
# [144949, 'cedar-forests', ['cedar']]
# [145047, 'fig-trees', ['fig', '-']]
# [145084, 'apricot-trees', ['apricot']]
# [145184, 'semi-tropical', ['semi']]
# [145372, 'date-palms', ['date']]
# [145726, 'tree-tops', ['tree']]
# [145756, 'summer-time', ['summer']]
# [145979, 'palm-trees', ['palm']]
# [146239, 'date-palms', ['date']]
# [146284, 'fruit-tree', ['fruit']]
# [146721, 'reddish-brown', ['reddish']]
# [146793, 'sienna-', ['sienna']]
# [147172, 'call-note', ['call']]
# [147211, 'Canar}', ['Canar}-']]
# [147217, '-', [',', 'a']]
# [147340, ':-', [':', '-', '"']]
# [147373, 'zi-zi', ['zi', '-', 'zi']]
# [147758, 'Vol', ['Vol.']]
# [147761, '.', ['XX']]
# [147767, 'p', ['p.', '289']]
# [147768, '.', ['289']]
# [147893, 'H', ['H.', 'C.']]
# [147894, '.', ['C.']]
# [147896, 'C', ['C.', 'Martin']]
# [147897, '.', ['Martin']]
# [148055, "Russ'", ['Russ']]
# [148148, 'Vol', ['Vol.']]
# [148151, '.', ['II']]
# [148157, 'pp', ['pp.']]
# [148159, '.', ['152-3']]
# [148219, 'sa3', ["sa3's"]]
# [148222, "'s", [':']]
# [148324, 'man}', ["man}'"]]
# [148328, "'", [',', 'however']]
# [148481, 'may-hope', ['may-']]
# [148521, 'Canar\\', ["Canar\\'"]]
# [148527, "'", ['and']]
# [148540, 'rape-seed', ['rape']]
# [148560, 'dail', ["dail}'"]]
# [148564, '}', ['addition']]
# [148565, "'", ['addition']]
# [148638, 'al\\va3', ["al\\va3's"]]
# [148644, "'s", ['found']]
# [148751, 'm', ["m}'"]]
# [148752, '}', ['mind']]
# [148753, "'", ['mind']]
# [149032, 'Ma}', ["Ma}'"]]
# [149035, "'", ['of']]
# [150066, 'cage-birds', ['cage']]
# [150246, 'care-fully', ['care']]
# [150384, 'cages-full', ['cages']]
# [150680, 'Familv---', ['Familv']]
# [150690, 'FRINGILLID', ['FRINGILLID. E']]
# [150702, 'E', ['.']]
# [150706, 'Subfawtly-FRINGILLIAVE', ['Subfawtly']]
# [150758, 'spinas', ['spinas.']]
# [150764, '.', [',', 'LiNN']]
# [151112, 'fir-woods', ['fir', '-']]
# [151633, 'hurdy-gurdy', ['hurdy']]
# [151942, 'olive-green', ['olive']]
# [151966, 'shaft-streaks', ['shaft']]
# [152020, 'shaft-streaks', ['shaft']]
# [152284, 'A', ["A'cllow"]]
# [152285, "'cllow", []]
# [152411, 'tail-feathers', ['tail']]
# [152639, 'ear-coverts', ['ear', '-']]
# [152691, '3', ["3'ellow"]]
# [152692, "'ellow", []]
# [152770, 'horn-brown', ['horn']]
# [153211, 'gre3', ["gre3'er"]]
# [153215, "'er", []]
# [153468, 'bird-', ['bird']]
# [153523, 'cage-birds', ['cage']]
# [153612, 'strongl', ["strongl}'"]]
# [153619, '}', ['of']]
# [153620, "'", ['of']]
# [153629, 'Tit-mice', ['Tit', '-']]
# [153854, 'call-note', ['call']]
# [153898, 'tit-tit-tit-iit', ['tit', '-']]
# [154072, 'aviar}-with', ['aviar}-']]
# [154153, 'probabl', ["probabl}'"]]
# [154160, '}', ['was']]
# [154161, "'", ['was']]
# [154326, 'call-note', ['call']]
# [154374, '/', ['///', ',']]
# [154375, '/', [',']]
# [154376, '/', [',', 'on']]
# [154477, 'R', ['R.', 'J.']]
# [154478, '.', ['J.']]
# [154480, 'J', ['J.', 'Ussher']]
# [154481, '.', ['Ussher']]
# [154621, ']Ma3', [']Ma3%']]
# [154625, '%', ['1857']]
# [154730, 'hill-side', ['hill']]
# [154880, 'cr3', ['cr3%']]
# [154883, '%', ['half']]
# [154921, 'fl3', ["fl3'ing"]]
# [154924, "'ing", []]
# [155122, 'oft', ['oft"']]
# [155125, '"', ['in']]
# [155184, 'awa3', ["awa3'"]]
# [155188, "'", ['.', 'Its']]
# [155306, 'particularl', ["particularl}'"]]
# [155317, '}', ['the']]
# [155318, "'", ['the']]
# [155433, 'fir-tree', ['fir', '-']]
# [155648, 'fir-tree', ['fir', '-']]
# [155823, 'fir-', ['fir', '-']]
# [155831, 'Ijirch-tree', ['Ijirch']]
# [156146, 'con-', ['con-↵ifers']]
# [156151, 'ifers', []]
# [156175, 'twenty-five', ['twenty']]
# [156532, 'bluish-green', ['bluish']]
# [156546, 'usuallj', ["usuallj'"]]
# [156553, "'", ['pale']]
# [156611, 'chocolate-brown', ['chocolate']]
# [156654, 'shell-markings', ['shell']]
# [157102, 'beech-mast', ['beech']]
# [157261, 'sow-thistle', ['sow', '-']]
# [157377, 'captivit}', ["captivit}'"]]
# [157386, "'", ['it']]
# [157765, 'wonderfull', ["wonderfull}'"]]
# [157775, '}', ['confiding']]
# [157776, "'", ['confiding']]
# [157901, 'aviar', ["aviar}'"]]
# [157906, '}', [';']]
# [157907, "'", [';']]
# [157944, 'thoroughl}-learned', ['thoroughl}-']]
# [158023, 'poppy-seed', ['poppy']]
# [158176, 'fl}', ["fl}'"]]
# [158179, "'", ['off']]
# [158207, 'directl', ["directl}'"]]
# [158214, '}', ['I']]
# [158215, "'", ['I']]
# [158432, 'there-fore', ['there']]
# [158742, 'man^-other', ['man^-']]
# [158831, 'alwaj', ["alwaj'S"]]
# [158836, "'S", ['become']]
# [158861, 'snrprisingh', ["snrprisingh'"]]
# [158872, "'", ['short']]
# [159259, '(every', ['(', 'every']]
# [159325, 'm', ["m}'"]]
# [159326, '}', ['large']]
# [159327, "'", ['large']]
# [159406, 'bird-room', ['bird']]
# [159526, 'presentl', ["presentl}'"]]
# [159534, '}', ['settled']]
# [159535, "'", ['settled']]
# [159745, 'half-an-hour', ['half']]
# [159815, '3', ["3'oung"]]
# [159816, "'oung", []]
# [159924, 'Family-', ['Family']]
# [159947, 'Subfamily-', ['Subfamily']]
# [159958, 'FKINGILLIN.F.', ['FKINGILLIN.F']]
# [159992, 'CJuysoinilt', ['CJuysoinilt is']]
# [160004, 'is', ['ciirinclla']]
# [160063, 'bird-catcher', ['bird']]
# [160099, 'Family-', ['Family']]
# [160107, 'FRIXG', ['FRIXG ILL ID. E']]
# [160113, 'ILL', []]
# [160117, 'ID.', []]
# [160121, 'E', ['.']]
# [160125, 'Sii/La,uily-LKL\\', ['Sii/La,uily']]
# [160142, "'(", []]
# [160145, 'i', []]
# [160146, '/L', []]
# [160149, 'L', []]
# [160151, 'LW', []]
# [160154, 'E', ['.']]
# [160185, 'clci^a', ['clci^a)is']]
# [160191, ')is', [',']]
# [160397, 'Eg3', ["Eg3'pt"]]
# [160400, "'pt", []]
# [160687, 'so-called', ['so', '-', 'called']]
# [160890, 'thirty-five', ['thirty']]
# [160992, 'pleasure-grounds', ['pleasure']]
# [161055, 'twenty-three', ['twenty']]
# [161123, 'summer-time', ['summer']]
# [161230, 'satinj', ["satinj'"]]
# [161236, "'-crimson", ['-', 'crimson']]
# [161549, 'snow-white', ['snow']]
# [161597, 'buffish-brown', ['buffish']]
# [161717, 'copper-brown', ['copper']]
# [161780, 'blue-black', ['blue']]
# [161828, 'Prussian-green', ['Prussian']]
# [161882, 'golden-yellow', ['golden']]
# [161908, 'two-thirds', ['two', '-']]
# [161985, 'golden-yellow', ['golden']]
# [162186, 'buffish-brown', ['buffish']]
# [162209, 'tail-coverts', ['tail']]
# [162243, 'buffish-brown', ['buffish']]
# [162318, 'reddish-buff', ['reddish']]
# [162346, 'blue-black', ['blue']]
# [162475, 'niostl', ["niostl}'"]]
# [162481, '}', ['white']]
# [162482, "'", ['white']]
# [162511, 'fore-chest', ['fore']]
# [162567, 'fawn-coloured', ['fawn']]
# [162589, 'tail-coverts', ['tail']]
# [162615, 'l', ['l)iiffish']]
# [162616, ')iiffish', []]
# [162632, 'pinkish-white', ['pinkish']]
# [162727, 'horu-browu', ['horu']]
# [162745, 'flesh-brown', ['flesh']]
# [162855, 'nsuall', ["nsuall}'"]]
# [162861, '}', ['.slightly']]
# [162862, "'", ['.slightly']]
# [163116, 'buff-brownish', ['buff']]
# [163155, 'distinctl', ["distinctl}'"]]
# [163164, '}', ['browner']]
# [163165, "'", ['browner']]
# [163261, 'mouse-brown', ['mouse']]
# [163438, 'bird-catchers', ['bird']]
# [163457, 'Gre3', ["Gre3'"]]
# [163461, "'-pates", ['-pates']]
# [163534, 'wing-feathers', ['wing']]
# [164195, 'note', ['note*']]
# [164199, '*', ['.']]
# [164765, 'to-wards', ['to', '-']]
# [164869, 'former!', ["former!}'"]]
# [164876, '}', ['was']]
# [164877, "'", ['was']]
# [165275, 'onl', ['onl}-']]
# [165278, '}-', ['capture']]
# [165320, '-market', ['-', 'market']]
# [165352, 'Sparrow-Hawk', ['Sparrow']]
# [165366, 'Hen-', ['Hen', '-']]
# [165473, 'close-seasons', ['close']]
# [165543, 'bird-catchers', ['bird']]
# [165573, 'Sparrow-Hawks', ['Sparrow']]
# [165613, 'decoy-Goldfinch', ['decoy']]
# [165730, 'prefer-abl}', ["prefer-↵abl}'"]]
# [165742, "'", ['on']]
# [165751, 'lichen-covered', ['lichen']]
# [165783, 'apple-tree', ['apple']]
# [165853, 'horse-chestnut', ['horse']]
# [166047, 'cup-shaped', ['cup', '-']]
# [166149, 'thistle-down', ['thistle']]
# [166188, 'horse-hair', ['horse']]
# [166282, 'W00II3', ["W00II3'"]]
# [166288, "'", ['substance']]
# [166349, 'thistle-down', ['thistle']]
# [166422, 'Rev', ['Rev.']]
# [166425, '.', ['H.']]
# [166427, 'H', ['H.', 'A.']]
# [166428, '.', ['A.']]
# [166430, 'A', ['A.', 'Macpherson']]
# [166431, '.', ['Macpherson']]
# [166483, 'Gold-finch', ['Gold']]
# [166615, 'l', ['l)uilt']]
# [166616, ')uilt', []]
# [166627, 'plum-tree', ['plum']]
# [166770, 'greenish-', ['greenish']]
# [166809, 'especiall', ["especiall}'"]]
# [166818, '}', ['at']]
# [166819, "'", ['at']]
# [166845, 'purplish-brown', ['purplish']]
# [166870, 'lilacine-grey', ['lilacine']]
# [166885, 'shell-spots', ['shell']]
# [166899, 'the3', ['the3%']]
# [166903, '%', ['however']]
# [166997, 'blood-', ['blood']]
# ...
# [455433, 'I', ['I.', "Irb}'"]]
# [455434, '.', ["Irb}'"]]
# [455436, 'Irb}', ["Irb}'"]]
# [455440, "'", [',', 'in']]
# [455494, 'sa3', ["sa3'S"]]
# [455497, "'S", ['that']]
# [455534, 'Wood-Lark', ['Wood']]
# [455670, '\\', ['\\&xy']]
# [455671, '&xy', []]
# [455777, 'Cork-wood', ['Cork']]
# [455788, 'Well-known', ['Well']]
# [455815, 'bird-catchers', ['bird']]
# [455853, 'cage-bird', ['cage']]
# [455890, 'Wood-Lark', ['Wood']]
# [455986, 'Wood-Lark', ['Wood']]
# [455999, 'onl', ["onl}'"]]
# [456002, '}', ['to']]
# [456003, "'", ['to']]
# [456262, 'necessary', ["necessary'"]]
# [456271, "'", ['to']]
# [456407, 'Wood-Lark', ['Wood']]
# [456561, 'grass-tussock', ['grass']]
# [456602, 'compactl', ["compactl}'"]]
# [456610, '}', ['built']]
# [456611, "'", ['built']]
# [456636, 'Sk^^-Lark', ['Sk^^']]
# [456661, 'couch-grass', ['couch']]
# [456954, '(Lilford', ['(', 'Lilford']]
# [457072, 'huffish-', ['huffish']]
# [457084, 'greenish-white', ['greenish']]
# [457113, 'reddish-brown', ['reddish']]
# [457131, 'brownish-lilac', ['brownish']]
# [457431, 'Sky-Lark', ['Sky', '-']]
# [457454, 'Wood-Lark', ['Wood']]
# [457470, 'generall', ["generall}'"]]
# [457478, '}', ['admitted']]
# [457479, "'", ['admitted']]
# [457498, 'nearly', ["nearly'"]]
# [457504, "'", ['resemble']]
# [457564, 'Wood-Lark', ['Wood']]
# [457577, 'double-brooded', ['double']]
# [457724, 'Sky-', ['Sky', '-']]
# [457802, 'Wood-Lark', ['Wood']]
# [457822, 'ver^', ["ver^'"]]
# [457826, "'", ['pnre']]
# [457927, 'certaiul', ["certaiul}'"]]
# [457935, '}', ['is']]
# [457936, "'", ['is']]
# [458250, 'flight-song', ['flight']]
# [458302, 'flute-like', ['flute']]
# [458526, 'Wood-Lark', ['Wood']]
# [458661, 'eye-streak', ['eye', '-']]
# [458895, 'Wood-Lark', ['Wood']]
# [459150, 'Tree-', ['Tree']]
# [459220, 'Sky-Lark', ['Sky', '-']]
# [459363, 'b', ["b}'"]]
# [459364, '}', ['jerky']]
# [459365, "'", ['jerky']]
# [459386, 'cage-bird', ['cage']]
# [459401, 'Wood-Lark', ['Wood']]
# [459685, 'me;', ['me', ';']]
# [460148, 'bird-catcher', ['bird']]
# [460190, 'Wood-Lark', ['Wood']]
# [460523, 'uncann', ["uncann}'"]]
# [460529, '}', [';']]
# [460530, "'", [';']]
# [460589, 'Wood-Lark', ['Wood']]
# [460690, 'in-', ['in', '-']]
# [460751, 'Sky-Lark', ['Sky', '-']]
# [460799, 'half-grown', ['half']]
# [460875, 'that', ["that'"]]
# [460879, "'", ['man']]
# [460942, 'B', ['B.', 'Farn']]
# [460943, '.', ['Farn']]
# [460965, 'Familx-ALA', ['Familx']]
# [460976, 'UDID', []]
# [460982, 'E', ['.']]
# [461231, 'east-ward', ['east']]
# [461896, 'greyish-brown', ['greyish']]
# [461981, 'tail-coverts', ['tail']]
# [462005, 'sandy-brown', ['sandy']]
# [462132, 'tail-feathers', ['tail']]
# [462296, 'sandv-buff', ['sandv']]
# [462321, 't', ['t)uter']]
# [462322, ')uter', []]
# [462419, 'buffish-white', ['buffish']]
# [462468, 'buffish-white', ['buffish']]
# [462546, 'blackish-brown', ['blackish']]
# [462683, 'horn-brown', ['horn']]
# [462853, 'sub-terminal', ['sub', '-']]
# [463072, 'Irb}', ['Irb}-']]
# [463076, '-', [',', 'in']]
# [463348, 'road-track', ['road']]
# [463397, 'onl', ["onl}'"]]
# [463400, '}', ['some']]
# [463401, "'", ['some']]
# [463443, 'fear-less', ['fear']]
# [463486, 'Curiiicit', ['Curiiicit)']]
# [463495, ')', [',', 'from']]
# [463594, 'mule-dung', ['mule']]
# [463726, 'sea-shore', ['sea', '-']]
# [464213, 'etc', ['etc.']]
# [464216, '.', [',', 'lined']]
# [464258, ':-', [':', '- -']]
# [464261, '-', ['"', 'The']]
# [464371, 'hoof-print', ['hoof']]
# [464603, 'greyish-white', ['greyish']]
# [464651, 'violet-grey', ['violet']]
# [464667, 'greenish-grey', ['greenish']]
# [464694, 'olive-brown', ['olive']]
# [464737, '"', ['"bS']]
# [464738, 'bS', ['in']]
# [464946, 'rapidit', ["rapidit}'"]]
# [464953, '}', [',']]
# [464954, "'", [',', 'while']]
# [465102, 'Wood-Lark', ['Wood']]
# [465142, 'generall', ["generall}'"]]
# [465150, '}', ['seen']]
# [465151, "'", ['seen']]
# [465166, '(', ['(U-']]
# [465167, 'U-', ['iu']]
# [465335, 'occasion-ally', ['occasion']]
# [465395, 'coo-hai', ['coo', '-']]
# [465576, 'etc', ['etc.']]
# [465579, '.', ['"', '"']]
# [465610, 'p', ['p.', '244']]
# [465611, '.', ['244']]
# [465625, 'sa3', ["sa3's"]]
# [465628, "'s", ['that']]
# [465875, 'ovato-pyriform', ['ovato']]
# [465890, '3-ellowish-white', ['3-ellowish']]
# [465936, 'greyish-yellow', ['greyish']]
# [466039, 'grass-hoppers', ['grass']]
# [466141, 'p', ['p.', '437']]
# [466142, '.', ['437']]
# [466412, 'A', ['A.', 'guli^iila']]
# [466413, '.', ['guli^iila']]
# [466772, 'Corn-', ['Corn']]
# [467220, 'etc', ['etc.']]
# [467223, '.', [',', 'etc.']]
# [467226, 'etc', ['etc.']]
# [467229, '.', ['"']]
# [467476, 'Corn-Bunting', ['Corn']]
# [467560, 'considerabl', ["considerabl}'"]]
# [467571, '}', ['as']]
# [467572, "'", ['as']]
# [467780, 'N.W.', ['N.W', '.']]
# [468160, 'the', ["the}'"]]
# [468163, '}', ['desire']]
# [468164, "'", ['desire']]
# [468272, 'P.Z.S.', ['P.Z.S']]
# [468279, '187', ['187 1']]
# [468283, '1', [',', 'p.']]
# [468286, 'p', ['p.', '390']]
# [468287, '.', ['390']]
# [468406, 'E', ['E.', 'Ind']]
# [468407, '.', ['Ind']]
# [468430, 'p', ['p.', '466']]
# [468431, '.', ['466']]
# [468922, 'etc', ['etc.']]
# [468925, '.', ['Familx']]
# [468928, 'Familx-ALA', ['Familx']]
# [468939, 'UDID^', []]
# [469168, 'G', ['G.', 'Dawson']]
# [469169, '.', ['Dawson']]
# [469637, 'Faunlx-ALAUDID.E', ['Faunlx']]
# [469673, 'Mcla', ['Mcla)iOLoyypha']]
# [469677, ')iOLoyypha', []]
# [469745, 'south-east', ['south']]
# [470101, 'cattle-truck', ['cattle']]
# [470411, 'man-assisted', ['man', '-']]
# [470436, 'Family-', ['Family']]
# [470444, 'ALAl', ["ALAl'DID.-Ji"]]
# [470448, "'DID.-Ji", []]
# [470463, 'Short-Toed', ['Short']]
# [470481, 'Ciila', ['Ciila)idixlla']]
# [470486, ')idixlla', []]
# [470693, 'hind-toe', ['hind']]
# [470907, 'North-west', ['North']]
# [470950, 'North-east', ['North']]
# [471050, 'North-west', ['North']]
# [471090, 'Short-toed', ['Short']]
# [471592, 'breeding-plumage', ['breeding']]
# [471627, 'sand3', ["sand3'"]]
# [471632, "'-browu", ['-', 'browu']]
# [471695, 'tail-feathers', ['tail']]
# [471713, 'smoky-brown', ['smoky']]
# [471852, 'Sky-Lark', ['Sky', '-']]
# [472056, 'horn-brown', ['horn']]
# [472367, 'Gibraltar"', ['Gibraltar']]
# [472383, ':-', [':', '-', '"']]
# [472405, 'side', ['side.']]
# [472409, '.', ['of']]
# [472735, 'au}', ["au}'"]]
# [472738, "'", ['sliglit']]
# [472829, 'l', ['l)ird']]
# [472830, ')ird', []]
# [472878, 'breeding-season', ['breeding']]
# [473029, 'difficult', ["difficult}'"]]
# [473038, '}', ['in']]
# [473039, "'", ['in']]
# [473297, 'jerk', ["jerk}'"]]
# [473301, '}', ['flight']]
# [473302, "'", ['flight']]
# [473423, 'Short-toed', ['Short']]
# [473945, 'grass-bents', ['grass']]
# [474104, 'Sky-Lark', ['Sky', '-']]
# [474346, 'Short-', ['Short']]
# [474362, 'Sky-Larks', ['Sky', '-']]
# [474489, 'creamy-whitish', ['creamy']]
# [474531, 'smoky-brown', ['smoky']]
# [474565, 'shell-spots', ['shell']]
# [474673, 'ground-tint', ['ground']]
# [474861, 'E', ['E.', 'I']]
# [474883, 'p', ['p.', '473']]
# [474884, '.', ['473']]
# [474929, 'table-land', ['table']]
# [475021, 'grass-downs', ['grass']]
# [475086, 'etc', ['etc.']]
# [475089, '.', [';']]
# [475111, 'grain-fields', ['grain']]
# [475302, 'p', ['p.', '427']]
# [475303, '.', ['427']]
# [475422, 'call-note', ['call']]
# [475588, 'man', ["man}'"]]
# [475591, '}', ['tliousand']]
# [475592, "'", ['tliousand']]
# [475760, 'bird-lime', ['bird']]
# [476069, 'alwa3', ["alwa3'S"]]
# [476074, "'S", ['called']]
# [476194, 'the', ["the}'"]]
# [476197, '}', ['breed']]
# [476198, "'", ['breed']]
# [476457, 'yellow-brown', ['yellow']]
# [476646, 'pp', ['pp.']]
# [476648, '.', ['359']]
# [476650, '359-360', ['359', '-']]
# [476801, 'solitar', ["solitar}'"]]
# [476808, '}', ['instances']]
# [476809, "'", ['instances']]
# [477342, 'ver', ["ver\\'"]]
# [477345, '\\', ['soon']]
# [477346, "'", ['soon']]
# [477365, "extraordinarilj'", ["extraordinarilj''"]]
# [477381, "'", ['tame']]
# [477628, 'Sk}--Lark', ['Sk}-']]
# [477652, 'Canary-seed', ['Canary']]
# [477764, 'Shore-Lark', ['Shore']]
# [477857, 'Familx-A', ['Familx']]
# [477866, 'LA', []]
# [477869, 'I', []]
# [477871, 'DID', []]
# [477876, 'E', ['.']]
# [477884, 'Shore-', ['Shore']]
# [477957, 'bej', ["bej'ond"]]
# [477960, "'ond", []]
# [477979, 'forest-', ['forest']]
# [478202, 'S', ['S.', 'Siberia']]
# [478203, '.', ['Siberia']]
# [478737, 'Shore-Lark', ['Shore']]
# [478806, 'ear-coverts', ['ear', '-']]
# [478900, 'fore-throat', ['fore']]
# [478912, 'creamy-white', ['creamy']]
# [479072, 'ear-coverts', ['ear', '-']]
# [479133, 'wing-coverts', ['wing']]
# [479157, 'tail-coverts', ['tail']]
# [479170, 'vinaceous-brown', ['vinaceous']]
# [479188, 'wing-coverts', ['wing']]
# [479228, 'smoky-brown', ['smoky']]
# [479293, 'ashy-margins', ['ashy']]
# [479329, 'greyish-brown', ['greyish']]
# [479392, 'tail-feathers', ['tail']]
# [479540, 'creamy-', ['creamy']]
# [480080, 'vShore-Lark', ['vShore']]
# [480226, 'entirely', ["entirely'"]]
# [480234, "'", ['a']]
# [480341, 'Shore-Lark', ['Shore']]
# [480412, 'melod3^', ['melod3']]
# [480489, 'Sky-Lark', ['Sky', '-']]
# [480689, 'arz', ["arz'i-fis/s"]]
# [480692, "'i-fis/s", []]
# [480709, '3', ["3'OU"]]
# [480710, "'OU", []]
# [480765, 'call-note', ['call']]
# [481232, 'etc', ['etc.']]
# [481235, '.', [';']]
# [481271, 'willow-down', ['willow']]
# [481440, 'Sky-Lark', ['Sky', '-']]
# [481733, 'Sky-Larks', ['Sky', '-']]
# [482433, '(doubtless', ['(', 'doubtless']]
# [482528, 'sea-shore', ['sea', '-']]
# [482585, 'Shore-', ['Shore']]
# [482860, 'Lark-like', ['Lark']]
# [482876, 'call-note', ['call']]
# [483025, 'captivit}', ["captivit}'"]]
# [483034, "'", [',', 'and']]
# [483208, 'prettily-marked', ['prettily']]
# [483238, 'cage-birds', ['cage']]
# [483499, 'so-called', ['so', '-', 'called']]
# [483759, 'Canary-seed', ['Canary']]
# [484202, 'Canar3^-seed', ['Canar3^']]
# [484267, 'Canar}', ["Canar}'"]]
# [484273, "'", [',', 'for']]
# [484446, 'ever', ["ever}'"]]
# [484450, '}', ['seed']]
# [484451, "'", ['seed']]
# [485179, 'hand-rear', ['hand']]
# [485260, 'bird-catcher', ['bird']]
# [485359, 'hand-reared', ['hand']]
# [486039, '-some', ['-', 'some']]
# [486066, 'man-assisted', ['man', '-']]
# [486251, 'Messrs', ['Messrs.']]
# [486257, '.', ['H.']]
# [486259, 'H', ['H.', 'F.']]
# [486260, '.', ['F.']]
# [486278, 'N', ['N.', 'F.']]
# [486279, '.', ['F.']]
# [486649, 'above-mentioned', ['above']]
# [486782, 'up-to-date', ['up', '-', 'to']]
# [486854, 'deficienc', ["deficienc}'"]]
# [486863, '}', ['here']]
# [486864, "'", ['here']]
# [486983, 'Family-', ['Family']]
# [487001, 'Subfamih-', ['Subfamih']]
# [487121, 'Notts', ['Notts.']]
# [487126, '.', [',', 'on']]
# [487198, 'Stornowa}', ['Stornowa}-']]
# [487207, '-', [',', 'Outer']]
# [487427, 'Ring-Ouzel', ['Ring']]
# [487500, 'Family-', ['Family']]
# [487508, 'Ti', ["Ti 'RDID. E"]]
# [487511, "'RDID", []]
# [487518, 'E', ['.']]
# [487522, 'Subfaniily-', ['Subfaniily']]
# [487534, 'TL', ["TL 'RUIN. E"]]
# [487537, "'RUIN", []]
# [487544, 'E', ['.']]
# [487552, 'Black-Eared', ['Black']]
# [487750, '3', ["3'ear"]]
# [487751, "'ear", []]
# [487912, 'Black-throated', ['Black']]
# [488104, 'Family-', ['Family']]
# [488112, 'TURD', ['TURD ID. E']]
# [488117, 'ID.', []]
# [488121, 'E', ['.']]
# [488125, 'Subfamily-', ['Subfamily']]
# [488292, '(vShetlands', ['(', 'vShetlands']]
# [488436, 'Messrs', ['Messrs.']]
# [488442, '.', ['Witherby']]
# [488589, ']', [']\\Iarch']]
# [488590, '\\Iarch', []]
# [488800, 'Family-', ['Family']]
# [488819, 'Subfamily-', ['Subfamily']]
# [488845, 'White-Spottf', ['White']]
# [488857, ':d', ['Bluethroat']]
# [488873, 'Cxa', ['Cxa)icciila']]
# [488876, ')icciila', []]
# [488885, 'u', ["u'i>l/l"]]
# [488886, "'i>l/l", []]
# [489042, 'Red-spotted', ['Red', '-']]
# [489248, 'Family-', ['Family']]
# [489266, 'Subfamily-', ['Subfamily']]
# [489644, '1', ['1 6th']]
# [489646, '6th', [',']]
# [489844, '-two', ['-', 'two']]
# [490002, '3', ["3'oung"]]
# [490003, "'oung", []]
# [490267, '1', ['1 5th']]
# [490269, '5th', [',']]
# [490416, 'Fawilx-', ['Fawilx']]
# [490424, 'TURD', ['TURD ID. -E']]
# [490429, 'ID.', []]
# [490433, '-', ['.']]
# [490434, 'E', ['.']]
# [490438, '5«', ['5«//rtw//r']]
# [490440, '/', []]
# [490441, '/rtw', []]
# [490445, '/', ['-']]
# [490446, '/r-', ['-']]
# [490450, '5', ['5 J Z I ILY^']]
# [490452, 'J', []]
# [490454, 'Z', []]
# [490456, 'I', []]
# [490458, 'ILY^', []]
# [490614, 'F.Z.S.', ['F.Z.S']]
# [490626, 'Fire-crested', ['Fire']]
# [490720, 'Yellow-browed', ['Yellow']]
# [490992, 'Family^', ['Family']]
# [491000, 'Ti', ['Ti 7^ DILL -E']]
# [491003, '7^', []]
# [491006, 'DILL', []]
# [491011, '-E', ['.']]
# [491016, 'SuhJaniiiy-SYL', ['SuhJaniiiy']]
# [491031, 'J', []]
# [491033, '7IA', []]
# [491036, '\\', ['.']]
# [491038, 'E', ['.']]
# [491042, "PallAvS'", ['PallAvS']]
# [491051, 'Willow-', ['Willow']]
# [491082, 'f^ivrcgit', ['f^ivrcgit/iis']]
# [491091, '/iis', []]
# [491274, '3', ["3'ear"]]
# [491275, "'ear", []]
# [491305, 'S', ['S.', 'Tnlloch']]
# [491306, '.', ['Tnlloch']]
# [491378, 'Family-', ['Family']]
# [491407, '-SYL', ['-', 'SYL I IIN.E']]
# [491412, 'I', []]
# [491414, 'IIN.E', []]
# [491448, 'Phy/', ['Phy//oscop!is']]
# [491452, '/oscop', []]
# [491458, '!is', []]
# [491544, 'Family-', ['Family']]
# [491552, 'TURDIL', ['TURDIL)^']]
# [491558, ')^', ['.']]
# [491563, 'Subfamily-', ['Subfamily']]
# [491574, 'SYL', ["SYL I 'IIN.E"]]
# [491578, 'I', []]
# [491580, "'IIN", []]
# [491585, 'E', ['.']]
# [491602, 'Willow-', ['Willow']]
# [491827, 'Willow-Warbler', ['Willow']]
# [491919, 'Wood-', ['Wood']]
# [491995, 'TL', ['TL ^RDID. E']]
# [491998, '^RDID', []]
# [492005, 'E', ['.']]
# [492009, 'Sii/^', ['Sii/^/,u>n/\\']]
# [492014, '/', []]
# [492015, ',u>n/', []]
# [492020, '\\-S', ['-', 'S J Z J VLV. E']]
# [492024, 'J', []]
# [492026, 'Z', []]
# [492028, 'J', []]
# [492030, 'VLV.', []]
# [492035, 'E', ['.']]
# [492066, '(', ['(^alcnimAs']]
# [492067, '^alcnimAs', []]
# [492152, 'Family-', ['Family']]
# [492171, 'Siih/auiilySYL', ['Siih/auiily']]
# [492186, 'I', []]
# [492188, 'IIN^E', []]
# [492200, 'Grey-Backed', ['Grey']]
# [492304, 'TURD', ['TURD ID ^']]
# [492309, 'ID', []]
# [492312, '^', ['.']]
# [492316, 'Subfamily-', ['Subfamily']]
# [492327, 'SYL', ['SYL I IIN^']]
# [492331, 'I', []]
# [492333, 'IIN^', []]
# [492348, 'Bush-Warbler', ['Bush']]
# [492499, 'Tl', ["Tl 'KDID. E"]]
# [492502, "'KDID", []]
# [492509, 'E', ['.']]
# [492513, 'Su/ifaniuy-SVL', ['Su/ifaniuy']]
# [492528, 'I', []]
# [492530, "'ILWF", []]
# [492538, 'Cetti', ["Cetti'vS"]]
# [492543, "'vS", []]
# [492617, 'Ma}', ["Ma}'"]]
# [492620, "'", ['12th']]
# [493049, 'Family-', ['Family']]
# [493067, 'Subfamily-', ['Subfamily']]
# [493078, 'SYL', ['SYL VIIN^']]
# [493082, 'VIIN^', []]
# [493281, 'Light-', ['Light']]
# [493339, 'Rev', ['Rev.']]
# [493342, '.', ['M.']]
# [493344, 'M', ['M.', 'A.']]
# [493345, '.', ['A.']]
# [493347, 'A', ['A.', 'Mathew']]
# [493348, '.', ['Mathew']]
# [493519, 'Reed-', ['Reed']]
# [493650, 'Marsh-', ['Marsh']]
# [493761, 'Reed-', ['Reed']]
# [494473, 'Januar}', ["Januar}'"]]
# [494480, "'", [',', '1905']]
# [494665, 'Scill', ["Scill}'"]]
# [494670, '}', ['.']]
# [494671, "'", ['.']]
# [494688, 'Long-', ['Long']]
# [494977, 'Wall-Creeper', ['Wall']]
# [495092, 'Family-', ['Family']]
# [495100, 'MO', ['MO TA CILLID. -E']]
# [495103, 'TA', []]
# [495106, 'CILLID', []]
# [495112, '.', []]
# [495114, '-', ['.']]
# [495115, 'E', ['.']]
# [495123, 'Grey-Headed', ['Grey']]
# [495145, 'j]', ['j] lot ac ilia']]
# [495148, 'lot', []]
# [495152, 'ac', []]
# [495155, 'ilia', []]
# [495194, 'Blue-headed', ['Blue']]
# [495256, '1', ['1 90 1']]
# [495258, '90', []]
# [495261, '1', ['one']]
# [495477, 'Family-', ['Family']]
# [495485, 'MO', ['MO TA CIL L ID^']]
# [495488, 'TA', []]
# [495491, 'CIL', []]
# [495495, 'L', []]
# [495497, 'ID^', ['.']]
# [495507, 'Black-Headed', ['Black']]
# [495641, 'flaz', ["flaz'a"]]
# [495645, "'a", [',']]
# [495676, 'Fa', ['Fa mi ly']]
# [495679, 'mi', []]
# [495682, 'ly-', ['-']]
# [495686, 'MO', ['MO TA CILL ID. F']]
# [495689, 'TA', []]
# [495692, 'CILL', []]
# [495697, 'ID.', []]
# [495701, 'F', ['.']]
# [495815, 'Family-', ['Family']]
# [495823, 'MO', ['MO TA CILLlDzE']]
# [495826, 'TA', []]
# [495829, 'CILLlDzE', []]
# [495844, 'AvShy-Headed', ['AvShy']]
# [495893, 'Sa', ["Sa\\'I"]]
# [495895, '\\', ['.']]
# [495896, "'I", ['.']]
# [495998, 'May?', ['May', '?']]
# [496084, 'sub-species', ['sub-']]
# [496103, 'M', ['M.', '/lava']]
# [496104, '.', ['/lava']]
# [496153, 'nowadaj', ["nowadaj'S"]]
# [496160, "'S", ['is']]
# [496221, 'Tree-Pipit', ['Tree']]
# [496317, 'W', ['W.', 'E.']]
# [496318, '.', ['E.']]
# [496320, 'E', ['E.', 'Clarke']]
# [496321, '.', ['Clarke']]
# [496393, 'Red-throated', ['Red', '-']]
# [496432, 'co', ['co.']]
# [496434, '.', ['Mayo']]
# [496474, 'co', ['co.']]
# [496476, '.', ['Donegal']]
# [497015, 'Water-', ['Water']]
# [497115, 'Scill3', ['Scill3%']]
# [497121, '%', ['May']]
# total:  99580  tp:  94769  fp:   4811  fn:   6940  prec: 0.9517  recall: 0.9318  f: 0.9416  err: 0.1103

# %%
""" Evaluate tokenization methods. """

print('waste-bnc'); print_eval_method(dic=gen_waste_dict(WASTE_BNC_PATH))
# print('waste-brown'); print_eval_method(dic=gen_waste_dict(WASTE_BROWN_PATH))
# print('waste-wsj'); print_eval_method(dic=gen_waste_dict(WASTE_WSJ_PATH))
# Out:
# waste-bnc
# total:  99531  tp:  94735  fp:   4796  fn:   6974  prec: 0.9518  recall: 0.9314  f: 0.9415  err: 0.1105

# %% [markdown]
# ## Evaluate on Penn Treebank

# %%
import re
import nltk
from nltk.corpus import treebank as ptb


def build_sent(words):
    sent = words[0]
    for i in range(1, len(words)):
        if re.search(r'[a-zA-Z]', words[i]):
            sent += ' '
        sent += words[i]
    return sent
    
def build_txt(sents):
    return ' '.join(build_sent(words) for words in sents)

print(dir(ptb))
print(len(ptb.fileids()))
for f in ptb.fileids():
    print(ptb.words(f))
    print(build_txt(ptb.sents(f)))
    break
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_comment_char', '_detect_blocks', '_encoding', '_fileids', '_get_root', '_normalize', '_parse', '_read_block', '_read_parsed_sent_block', '_read_sent_block', '_read_tagged_sent_block', '_read_tagged_word_block', '_read_word_block', '_root', '_tag', '_tagset', '_unload', '_word', 'abspath', 'abspaths', 'citation', 'encoding', 'ensure_loaded', 'fileids', 'license', 'open', 'parsed_sents', 'raw', 'readme', 'root', 'sents', 'tagged_sents', 'tagged_words', 'unicode_repr', 'words']
# 199
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', ...]
# Pierre Vinken,61 years old, will join the board as a nonexecutive director Nov.29. Mr. Vinken is chairman of Elsevier N.V., the Dutch publishing group.
